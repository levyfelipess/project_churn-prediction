# %%
import numpy as np
from numpy import format_float_positional as ffp
from scipy import stats as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(context='notebook', style='ticks')
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['mathtext.fontset'] = 'cm'

# %% [markdown]
# # Análise Preliminar
# ---
# #### Conclusões:
# 1. 20 variáveis no total, sendo:
#     - 1 variável de saída, coluna `Churn`, categórica binária e 19 variáveis de entrada;
#     - 3 variáveis numéricas, 7 variáveis categóricas binárias e 10 variáveis categóricas multiclasse;
# 2. Houve necessidade de conversão de tipos;
# 3. Poucos valores faltantes, preenchidos pela repetição dos valores de outra variável;
# ---

# %% [markdown]
# ## Visão Geral do *Dataset*

# %%
df = pd.read_csv('data/WA_Fn-UseC_-Telco-Customer-Churn.csv')
display(df.head())
display(df.info())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Algumas etapas preliminares básicas de limpeza e pré-processamento de dados
# - Remoção da coluna `customerID`;
# - Conversão de tipo da coluna `SeniorCitizen`, de `int64` para `object` (trata-se de uma variável categórica);
# - Conversão de tipo da coluna `TotalCharges`, de `object` para `float64` (trata-se de uma variável numérica);
# - Conversão de tipo da coluna `tenure`, de `int64` para `float64` (somente para facilitar processamentos posteriores);
# - Identificação das linhas da coluna `TotalCharges` com valor `' '` e preenchimento com a repetição do valor correspondente da coluna `MonthlyCharges`, pois foi observado que estes valores ausentes correspondiam todos à clientes cujo tempo de permanência fora 0 meses (variável `tenure`), portanto, é razoável assumir que o total corresponderia à única recarga que haviam realizado.

# %%
df = df.drop(columns='customerID')

col_missing_values = np.where(df['TotalCharges'] == ' ')[0]
df.loc[col_missing_values, 'TotalCharges'] = df.loc[col_missing_values, 'MonthlyCharges']
del col_missing_values

df = df.astype({'SeniorCitizen':'object', 'tenure':'float64', 'TotalCharges':'float64'})

display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   object
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   float64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.describe(include='object').loc['unique']
# Out:
# gender              2
# SeniorCitizen       2
# Partner             2
# Dependents          2
# PhoneService        2
# MultipleLines       3
# InternetService     3
# OnlineSecurity      3
# OnlineBackup        3
# DeviceProtection    3
# TechSupport         3
# StreamingTV         3
# StreamingMovies     3
# Contract            3
# PaperlessBilling    2
# PaymentMethod       4
# Churn               2
# Name: unique, dtype: object

# %% [markdown]
# # Análises Univariadas

# %% [markdown]
# ## Análises Tabulares

# %%
df.describe(include='object').T
# Out:
#                  count unique               top  freq
# gender            7043      2              Male  3555
# SeniorCitizen     7043      2                 0  5901
# Partner           7043      2                No  3641
# Dependents        7043      2                No  4933
# PhoneService      7043      2               Yes  6361
# MultipleLines     7043      3                No  3390
# InternetService   7043      3       Fiber optic  3096
# OnlineSecurity    7043      3                No  3498
# OnlineBackup      7043      3                No  3088
# DeviceProtection  7043      3                No  3095
# TechSupport       7043      3                No  3473
# StreamingTV       7043      3                No  2810
# StreamingMovies   7043      3                No  2785
# Contract          7043      3    Month-to-month  3875
# PaperlessBilling  7043      2               Yes  4171
# PaymentMethod     7043      4  Electronic check  2365
# ...

# %%
df.describe(include='float64')
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7043.000000
# mean     32.371149       64.761692   2279.798992
# std      24.559481       30.090047   2266.730170
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    398.550000
# 50%      29.000000       70.350000   1394.550000
# 75%      55.000000       89.850000   3786.600000
# max      72.000000      118.750000   8684.800000

# %% [markdown]
# ## Análises Gráficas

# %% [markdown]
# ### Variáveis Numéricas

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4), layout='constrained')
sns.histplot(ax=ax[0], data=df, x='tenure', color='black')
sns.histplot(ax=ax[1], data=df, x='tenure', color='black', hue='Churn')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 4), layout='constrained')
sns.boxplot(ax=ax[0], data=df, y='tenure', color='gray', linecolor='black', width=0.2)
ax[0].set_xticks([])
sns.boxplot(ax=ax[1], data=df, y='tenure', x='Churn', color='gray', linecolor='black', width=.2)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4), layout='constrained')
sns.histplot(ax=ax[0], data=df, x='MonthlyCharges', color='black')
sns.histplot(ax=ax[1], data=df, x='MonthlyCharges', hue='Churn')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 4), layout='constrained')
sns.boxplot(ax=ax[0], data=df, y='MonthlyCharges', color='gray', linecolor='black', width=0.2)
ax[0].set_xticks([])
sns.boxplot(ax=ax[1], data=df, y='MonthlyCharges', x='Churn', color='gray', linecolor='black', width=.2)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4), layout='constrained')
sns.histplot(ax=ax[0], data=df, x='TotalCharges', color='black')
sns.histplot(ax=ax[1], data=df, x='TotalCharges', hue='Churn')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 4), layout='constrained')
sns.boxplot(ax=ax[0], data=df, y='TotalCharges', color='gray', linecolor='black', width=0.2)
ax[0].set_xticks([])
sns.boxplot(ax=ax[1], data=df, y='TotalCharges', x='Churn', color='gray', linecolor='black', width=.2)
plt.show()

# %% [markdown]
# ### Variáveis Categóricas

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 4), layout='constrained')
feature = 'Churn'
sns.countplot(ax=ax, data=df, x=feature, stat='percent', color='gray', width=.5)
ax.set_ylabel('Percentual')
ax.set_xlabel('Classe')
ax.set_title('Distribuição das Classes da Variável "'+feature+'"')
plt.show()

# %%
def barplot_with_percent_inclass(df, feature, target, figsize=(8, 4)):
    contingency_table = st.contingency.crosstab(df.loc[:, feature], df.loc[:, target])
    class_order = contingency_table.elements[0]
    target_class_percent = np.round(contingency_table.count / contingency_table.count.sum(axis=1).reshape(-1, 1) * 100, 1)
    fig, ax = plt.subplots(1, 2, figsize=figsize, layout='constrained')
    sns.countplot(ax=ax[0], data=df, x=feature, order=class_order, stat='percent', color='gray', width=.5)
    sns.countplot(ax=ax[1], data=df, x=feature, hue=target, order=class_order, stat='count')
    ax[1].bar_label(ax[1].containers[0], labels=target_class_percent[:, 0], size=10)
    ax[1].bar_label(ax[1].containers[1], labels=target_class_percent[:, 1], size=10)
    ax[0].set_ylabel('Percentual')
    ax[1].set_ylabel('Contagem')
    ax[0].set_xlabel('Classe')
    ax[1].set_xlabel('Classe')
    fig.suptitle('Distribuição das Classes da Variável "' + feature + '"')
    ax[0].set_title('Todas as amostras')
    ax[1].set_title('Condicionadas pela classe da saída')
    plt.show()

# %%
barplot_with_percent_inclass(df, 'Contract', 'Churn')

# %%
barplot_with_percent_inclass(df, 'OnlineSecurity', 'Churn')

# %%
barplot_with_percent_inclass(df, 'PaymentMethod', 'Churn', figsize=(10, 4))

# %%
barplot_with_percent_inclass(df, 'OnlineSecurity', 'Churn')

# %% [markdown]
# # Análises Bivariadas

# %%
fig, ax = plt.subplots(1, 3, figsize=(3*3, 4), layout='constrained')
sns.heatmap(df.loc[:, df.dtypes=='float64'].corr('pearson'), ax=ax[0], annot=True, annot_kws={'size':10}, fmt='.4f', cmap='RdBu', vmin=-1, vmax=1)
plt.show()

# %%
#fig, ax = plt.subplots(1, 1, figsize=(4.5, 3.5), layout='constrained')
sns.pairplot(df.loc[:, list(df.columns[df.dtypes=='float64']) + ['Churn']], hue='Churn', markers=['o', 's'], height=2, plot_kws={'s':15, 'alpha':.5})
plt.show()

# %%
st.contingency.chi2_contingency(st.contingency.crosstab(df.loc[:, 'PhoneService'], df.loc[:, 'MultipleLines']).count)
# Out:
# Chi2ContingencyResult(statistic=np.float64(7042.999999999998), pvalue=np.float64(0.0), dof=2, expected_freq=array([[ 328.26636377,   66.0406077 ,  287.69302854],
#        [3061.73363623,  615.9593923 , 2683.30697146]]))

# %%
def contingency_association_matrix(df, method='cramer'):
    d = df.shape[1]
    cont_df = pd.DataFrame(np.eye(d),
                           columns=df.columns, index=df.columns)

    for i in range(d):
        for j in range(i+1, d):
            contingency_table = st.contingency.crosstab(df.iloc[:, i], df.iloc[:, j])
            cont_df.iloc[i, j] = st.contingency.association(observed=contingency_table.count, method=method, correction=True)
            cont_df.iloc[j, i] = cont_df.iloc[i, j]

    return cont_df

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 9), layout='constrained')
cont_ass_matrix = contingency_association_matrix(df.loc[:, df.dtypes=='object'], method='cramer')
sns.heatmap(cont_ass_matrix, ax=ax, annot=True, annot_kws={'size':10}, fmt='.4f', cmap='Blues', vmin=0, vmax=1)
plt.show()
