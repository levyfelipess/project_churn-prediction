# %% [markdown]
# # *Setup*

# %%
import numpy as np
from numpy import format_float_positional as ffp
from scipy import stats
import pandas as pd
from time import perf_counter

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

from xgboost import XGBClassifier

from churn_proj.preprocessing import clean_data_modeling, get_transformers
from churn_proj.modeling import train_model, random_search_with_kfoldcv, parallelized_random_search_with_kfoldcv
from churn_proj.evaluation import evaluate, display_best_hyperparam_combinations
from churn_proj.utils import save_models, load_models

# %%
df = pd.read_csv('../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df_X, df_y = clean_data_modeling(df=df)
#df_X.to_csv('../data/processed/WA_Fn-UseC_-Telco-Customer-Churn_modeling_X.csv')
#df_y.to_csv('../data/processed/WA_Fn-UseC_-Telco-Customer-Churn_modeling_y.csv')

df_X_train, df_X_test, df_y_train, df_y_test = train_test_split(df_X, df_y, test_size=0.25, shuffle=True, stratify=df_y, random_state=7)
print('Training Dataset:', df_X_train.shape, df_y_train.shape)
print('Test Dataset:', df_X_test.shape, df_y_test.shape)

transformers_X, transformer_y = get_transformers(df_X=df_X, df_y=df_y)

models = {}
# Out:
# Training Dataset: (5282, 17) (5282, 1)
# Test Dataset: (1761, 17) (1761, 1)

# %% [markdown]
# # Training and Model Evaluation
# ###### **(PT-BR) Treinamento e Avaliação Individual dos Modelos**

# %% [markdown]
# ## ***Baseline***: Logistic Regression (**LR**)
# ###### **(PT-BR) Regressão Logística**

# %%
X_train_transformed = transformers_X['LR'].fit_transform(df_X_train)
X_test_transformed = transformers_X['LR'].transform(df_X_test)
y_train = transformer_y.fit_transform(df_y_train)
y_test  = transformer_y.transform(df_y_test)

# %%
models['LR'] = LogisticRegression(C=np.inf,
                                  tol=1e-4,
                                  fit_intercept=True,
                                  solver='lbfgs',
                                  max_iter=1000,
                                  n_jobs=1,
                                  random_state=7)

train_model(model=models['LR'],
            X=X_train_transformed, y=y_train.reshape(-1),
            display_language='en')
# Out:
# Total Time: 0 s = 0.0 min = 0.0 h
#             0h 00min 00s

# %%
_ = evaluate(
    model=models['LR'],
    X_train=X_train_transformed, X_test=X_test_transformed, y_train=y_train, y_test=y_test,
    beta_fscore=2, threshold=0.5, threshold_step=0.001,
    display_metrics_table=True, plot_confusion_matrix=True, plot_roc_pr_curve=True,
    save_metrics_table=True, save_confusion_matrix=True, save_roc_pr_curve=True,
    path_metrics_table='../reports/tables/model-evaluation_LR.csv',
    path_confusion_matrix='../reports/figures/en/confusion-matrix_LR.png',
    path_roc_pr_curve='../reports/figures/en/roc-pr-curves_LR.png',
    model_title=' - LR', plot_display_language='en')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e187e">
#   <caption>Evaluation Metrics - LR</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e187e_level0_col0" class="col_heading level0 col0" >Training</th>
#       <th id="T_e187e_level0_col1" class="col_heading level0 col1" >Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e187e_level0_row0" class="row_heading level0 row0" >Accuracy</th>
#       <td id="T_e187e_row0_col0" class="data row0 col0" >0.808</td>
#       <td id="T_e187e_row0_col1" class="data row0 col1" >0.810</td>
#     </tr>
#     <tr>
#       <th id="T_e187e_level0_row1" class="row_heading level0 row1" >Precision</th>
#       <td id="T_e187e_row1_col0" class="data row1 col0" >0.667</td>
#       <td id="T_e187e_row1_col1" class="data row1 col1" >0.672</td>
#     </tr>
#     <tr>
#       <th id="T_e187e_level0_row2" class="row_heading level0 row2" >Recall</th>
#       <td id="T_e187e_row2_col0" class="data row2 col0" >0.553</td>
#       <td id="T_e187e_row2_col1" class="data row2 col1" >0.552</td>
#     </tr>
#     <tr>
#       <th id="T_e187e_level0_row3" class="row_heading level0 row3" >F1-Score</th>
#       <td id="T_e187e_row3_col0" class="data row3 col0" >0.605</td>
#       <td id="T_e187e_row3_col1" class="data row3 col1" >0.606</td>
#     </tr>
#     <tr>
#       <th id="T_e187e_level0_row4" class="row_heading level0 row4" >F2.-Score</th>
#       <td id="T_e187e_row4_col0" class="data row4 col0" >0.573</td>
#       <td id="T_e187e_row4_col1" class="data row4 col1" >0.573</td>
#     </tr>
#     <tr>
#       <th id="T_e187e_level0_row5" class="row_heading level0 row5" >AUROC</th>
#       <td id="T_e187e_row5_col0" class="data row5 col0" >-----</td>
#       <td id="T_e187e_row5_col1" class="data row5 col1" >0.858</td>
#     </tr>
#     <tr>
#       <th id="T_e187e_level0_row6" class="row_heading level0 row6" >AUPR</th>
#       <td id="T_e187e_row6_col0" class="data row6 col0" >-----</td>
#       <td id="T_e187e_row6_col1" class="data row6 col1" >0.679</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Decision Tree (**DT**)
# ###### **(PT-BR) Árvore de Decisão**

# %% [markdown]
# ### Hyperparameter Optimization
# ###### **(PT-BR) Otimização de Hiperparâmetros**

# %%
hyperparam_dist = {'ccp_alpha':stats.loguniform(a=1e-4, b=1e3),
                   'criterion':['gini', 'entropy'],
                   'min_samples_split':stats.randint(2, 40+1)}

df_hyperparam_optimization = parallelized_random_search_with_kfoldcv(model=DecisionTreeClassifier(random_state=7),
                                                                     n_comb=1000, k=5,
                                                                     transformer_X=transformers_X['DT'], transformer_y=transformer_y,
                                                                     df_X_train=df_X_train, df_y_train=df_y_train,
                                                                     hyperparam_distributions=hyperparam_dist,
                                                                     n_jobs=5,
                                                                     global_seed=7,
                                                                     display_language='en')

df_hyperparam_optimization.to_csv('../reports/tables/hyperparam-optimization_DT.csv')

display_best_hyperparam_combinations(df=df_hyperparam_optimization,
                                     n_best=None, sort_by='min_samples_split', ascending=False,
                                     with_one_standard_error_rule=True,
                                     metric_mean_column='auc (mean)',
                                     metric_se_column='auc (se)',
                                     style_format={'ccp_alpha':lambda x: ffp(x)})
# Out:
# Total Time: 69 s = 1.2 min = 0.0 h
#             0h 01min 09s
# <style type="text/css">
# </style>
# <table id="T_09c2a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09c2a_level0_col0" class="col_heading level0 col0" >ccp_alpha</th>
#       <th id="T_09c2a_level0_col1" class="col_heading level0 col1" >criterion</th>
#       <th id="T_09c2a_level0_col2" class="col_heading level0 col2" >min_samples_split</th>
#       <th id="T_09c2a_level0_col3" class="col_heading level0 col3" >auc (mean)</th>
#       <th id="T_09c2a_level0_col4" class="col_heading level0 col4" >auc (std)</th>
#       <th id="T_09c2a_level0_col5" class="col_heading level0 col5" >auc (se)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09c2a_level0_row0" class="row_heading level0 row0" >447</th>
#       <td id="T_09c2a_row0_col0" class="data row0 col0" >0.0028075893645747984</td>
#       <td id="T_09c2a_row0_col1" class="data row0 col1" >entropy</td>
#       <td id="T_09c2a_row0_col2" class="data row0 col2" >38</td>
#       <td id="T_09c2a_row0_col3" class="data row0 col3" >0.824055</td>
#       <td id="T_09c2a_row0_col4" class="data row0 col4" >0.008793</td>
#       <td id="T_09c2a_row0_col5" class="data row0 col5" >0.003932</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row1" class="row_heading level0 row1" >415</th>
#       <td id="T_09c2a_row1_col0" class="data row1 col0" >0.002220981905763782</td>
#       <td id="T_09c2a_row1_col1" class="data row1 col1" >entropy</td>
#       <td id="T_09c2a_row1_col2" class="data row1 col2" >36</td>
#       <td id="T_09c2a_row1_col3" class="data row1 col3" >0.824147</td>
#       <td id="T_09c2a_row1_col4" class="data row1 col4" >0.010528</td>
#       <td id="T_09c2a_row1_col5" class="data row1 col5" >0.004708</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row2" class="row_heading level0 row2" >184</th>
#       <td id="T_09c2a_row2_col0" class="data row2 col0" >0.0022261659343238895</td>
#       <td id="T_09c2a_row2_col1" class="data row2 col1" >entropy</td>
#       <td id="T_09c2a_row2_col2" class="data row2 col2" >36</td>
#       <td id="T_09c2a_row2_col3" class="data row2 col3" >0.824147</td>
#       <td id="T_09c2a_row2_col4" class="data row2 col4" >0.010528</td>
#       <td id="T_09c2a_row2_col5" class="data row2 col5" >0.004708</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row3" class="row_heading level0 row3" >219</th>
#       <td id="T_09c2a_row3_col0" class="data row3 col0" >0.002071140208814707</td>
#       <td id="T_09c2a_row3_col1" class="data row3 col1" >entropy</td>
#       <td id="T_09c2a_row3_col2" class="data row3 col2" >32</td>
#       <td id="T_09c2a_row3_col3" class="data row3 col3" >0.824378</td>
#       <td id="T_09c2a_row3_col4" class="data row3 col4" >0.008559</td>
#       <td id="T_09c2a_row3_col5" class="data row3 col5" >0.003828</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row4" class="row_heading level0 row4" >778</th>
#       <td id="T_09c2a_row4_col0" class="data row4 col0" >0.0020716321265925354</td>
#       <td id="T_09c2a_row4_col1" class="data row4 col1" >entropy</td>
#       <td id="T_09c2a_row4_col2" class="data row4 col2" >31</td>
#       <td id="T_09c2a_row4_col3" class="data row4 col3" >0.824378</td>
#       <td id="T_09c2a_row4_col4" class="data row4 col4" >0.008559</td>
#       <td id="T_09c2a_row4_col5" class="data row4 col5" >0.003828</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row5" class="row_heading level0 row5" >908</th>
#       <td id="T_09c2a_row5_col0" class="data row5 col0" >0.0020280358191880976</td>
#       <td id="T_09c2a_row5_col1" class="data row5 col1" >entropy</td>
#       <td id="T_09c2a_row5_col2" class="data row5 col2" >31</td>
#       <td id="T_09c2a_row5_col3" class="data row5 col3" >0.823948</td>
#       <td id="T_09c2a_row5_col4" class="data row5 col4" >0.007217</td>
#       <td id="T_09c2a_row5_col5" class="data row5 col5" >0.003227</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row6" class="row_heading level0 row6" >453</th>
#       <td id="T_09c2a_row6_col0" class="data row6 col0" >0.0026797550974218065</td>
#       <td id="T_09c2a_row6_col1" class="data row6 col1" >entropy</td>
#       <td id="T_09c2a_row6_col2" class="data row6 col2" >29</td>
#       <td id="T_09c2a_row6_col3" class="data row6 col3" >0.825207</td>
#       <td id="T_09c2a_row6_col4" class="data row6 col4" >0.009578</td>
#       <td id="T_09c2a_row6_col5" class="data row6 col5" >0.004283</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row7" class="row_heading level0 row7" >378</th>
#       <td id="T_09c2a_row7_col0" class="data row7 col0" >0.0017907619083377857</td>
#       <td id="T_09c2a_row7_col1" class="data row7 col1" >entropy</td>
#       <td id="T_09c2a_row7_col2" class="data row7 col2" >24</td>
#       <td id="T_09c2a_row7_col3" class="data row7 col3" >0.822683</td>
#       <td id="T_09c2a_row7_col4" class="data row7 col4" >0.007146</td>
#       <td id="T_09c2a_row7_col5" class="data row7 col5" >0.003196</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row8" class="row_heading level0 row8" >858</th>
#       <td id="T_09c2a_row8_col0" class="data row8 col0" >0.0018400565213841874</td>
#       <td id="T_09c2a_row8_col1" class="data row8 col1" >entropy</td>
#       <td id="T_09c2a_row8_col2" class="data row8 col2" >22</td>
#       <td id="T_09c2a_row8_col3" class="data row8 col3" >0.822622</td>
#       <td id="T_09c2a_row8_col4" class="data row8 col4" >0.007976</td>
#       <td id="T_09c2a_row8_col5" class="data row8 col5" >0.003567</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row9" class="row_heading level0 row9" >187</th>
#       <td id="T_09c2a_row9_col0" class="data row9 col0" >0.0027797196395198728</td>
#       <td id="T_09c2a_row9_col1" class="data row9 col1" >entropy</td>
#       <td id="T_09c2a_row9_col2" class="data row9 col2" >18</td>
#       <td id="T_09c2a_row9_col3" class="data row9 col3" >0.824240</td>
#       <td id="T_09c2a_row9_col4" class="data row9 col4" >0.008740</td>
#       <td id="T_09c2a_row9_col5" class="data row9 col5" >0.003908</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row10" class="row_heading level0 row10" >822</th>
#       <td id="T_09c2a_row10_col0" class="data row10 col0" >0.002446259192894188</td>
#       <td id="T_09c2a_row10_col1" class="data row10 col1" >entropy</td>
#       <td id="T_09c2a_row10_col2" class="data row10 col2" >17</td>
#       <td id="T_09c2a_row10_col3" class="data row10 col3" >0.823511</td>
#       <td id="T_09c2a_row10_col4" class="data row10 col4" >0.010601</td>
#       <td id="T_09c2a_row10_col5" class="data row10 col5" >0.004741</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row11" class="row_heading level0 row11" >592</th>
#       <td id="T_09c2a_row11_col0" class="data row11 col0" >0.0022897133444280686</td>
#       <td id="T_09c2a_row11_col1" class="data row11 col1" >entropy</td>
#       <td id="T_09c2a_row11_col2" class="data row11 col2" >15</td>
#       <td id="T_09c2a_row11_col3" class="data row11 col3" >0.823860</td>
#       <td id="T_09c2a_row11_col4" class="data row11 col4" >0.010740</td>
#       <td id="T_09c2a_row11_col5" class="data row11 col5" >0.004803</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row12" class="row_heading level0 row12" >950</th>
#       <td id="T_09c2a_row12_col0" class="data row12 col0" >0.0025588536991464654</td>
#       <td id="T_09c2a_row12_col1" class="data row12 col1" >entropy</td>
#       <td id="T_09c2a_row12_col2" class="data row12 col2" >11</td>
#       <td id="T_09c2a_row12_col3" class="data row12 col3" >0.825327</td>
#       <td id="T_09c2a_row12_col4" class="data row12 col4" >0.009445</td>
#       <td id="T_09c2a_row12_col5" class="data row12 col5" >0.004224</td>
#     </tr>
#     <tr>
#       <th id="T_09c2a_level0_row13" class="row_heading level0 row13" >734</th>
#       <td id="T_09c2a_row13_col0" class="data row13 col0" >0.0025780863732141517</td>
#       <td id="T_09c2a_row13_col1" class="data row13 col1" >entropy</td>
#       <td id="T_09c2a_row13_col2" class="data row13 col2" >11</td>
#       <td id="T_09c2a_row13_col3" class="data row13 col3" >0.825327</td>
#       <td id="T_09c2a_row13_col4" class="data row13 col4"

# %% [markdown]
# ### Final Training and Evaluation
# ###### **(PT-BR) Treinamento final e Avaliação**

# %%
X_train_transformed = transformers_X['DT'].fit_transform(df_X_train)
X_test_transformed = transformers_X['DT'].transform(df_X_test)
y_train = transformer_y.fit_transform(df_y_train)
y_test  = transformer_y.transform(df_y_test)

# %%
# Combinação de hiperparâmetros nº 447
models['DT'] = DecisionTreeClassifier(ccp_alpha=0.0028075893645747984,
                                      min_samples_split=38,
                                      criterion='entropy',
                                      random_state=7)

train_model(model=models['DT'],
            X=X_train_transformed, y=y_train.reshape(-1),
            display_language='en')
# Out:
# Total Time: 0 s = 0.0 min = 0.0 h
#             0h 00min 00s

# %%
_ = evaluate(
    model=models['DT'],
    X_train=X_train_transformed, X_test=X_test_transformed, y_train=y_train, y_test=y_test,
    beta_fscore=2, threshold=0.5, threshold_step=0.001,
    display_metrics_table=True, plot_confusion_matrix=True, plot_roc_pr_curve=True,
    save_metrics_table=True, save_confusion_matrix=True, save_roc_pr_curve=True,
    path_metrics_table='../reports/tables/model-evaluation_DT.csv',
    path_confusion_matrix='../reports/figures/en/confusion-matrix_DT.png',
    path_roc_pr_curve='../reports/figures/en/roc-pr-curves_DT.png',
    model_title=' - DT', plot_display_language='en')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d21e8">
#   <caption>Evaluation Metrics - DT</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d21e8_level0_col0" class="col_heading level0 col0" >Training</th>
#       <th id="T_d21e8_level0_col1" class="col_heading level0 col1" >Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d21e8_level0_row0" class="row_heading level0 row0" >Accuracy</th>
#       <td id="T_d21e8_row0_col0" class="data row0 col0" >0.791</td>
#       <td id="T_d21e8_row0_col1" class="data row0 col1" >0.793</td>
#     </tr>
#     <tr>
#       <th id="T_d21e8_level0_row1" class="row_heading level0 row1" >Precision</th>
#       <td id="T_d21e8_row1_col0" class="data row1 col0" >0.684</td>
#       <td id="T_d21e8_row1_col1" class="data row1 col1" >0.677</td>
#     </tr>
#     <tr>
#       <th id="T_d21e8_level0_row2" class="row_heading level0 row2" >Recall</th>
#       <td id="T_d21e8_row2_col0" class="data row2 col0" >0.392</td>
#       <td id="T_d21e8_row2_col1" class="data row2 col1" >0.418</td>
#     </tr>
#     <tr>
#       <th id="T_d21e8_level0_row3" class="row_heading level0 row3" >F1-Score</th>
#       <td id="T_d21e8_row3_col0" class="data row3 col0" >0.499</td>
#       <td id="T_d21e8_row3_col1" class="data row3 col1" >0.517</td>
#     </tr>
#     <tr>
#       <th id="T_d21e8_level0_row4" class="row_heading level0 row4" >F2.-Score</th>
#       <td id="T_d21e8_row4_col0" class="data row4 col0" >0.429</td>
#       <td id="T_d21e8_row4_col1" class="data row4 col1" >0.452</td>
#     </tr>
#     <tr>
#       <th id="T_d21e8_level0_row5" class="row_heading level0 row5" >AUROC</th>
#       <td id="T_d21e8_row5_col0" class="data row5 col0" >-----</td>
#       <td id="T_d21e8_row5_col1" class="data row5 col1" >0.837</td>
#     </tr>
#     <tr>
#       <th id="T_d21e8_level0_row6" class="row_heading level0 row6" >AUPR</th>
#       <td id="T_d21e8_row6_col0" class="data row6 col0" >-----</td>
#       <td id="T_d21e8_row6_col1" class="data row6 col1" >0.665</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Random Forest (**RF**)
# ###### **(PT-BR) Floresta Aleatória**

# %% [markdown]
# ### Hyperparameter Optimization
# ###### **(PT-BR) Otimização de Hiperparâmetros**

# %%
hyperparam_dist = {'n_estimators':stats.randint(10, 500+1),
                   'criterion':['gini', 'entropy'],
                   'max_features':stats.uniform(0, 1),
                   'max_depth':list(range(2, 20+1, 2)) + [None]}

df_hyperparam_optimization = random_search_with_kfoldcv(model=RandomForestClassifier(random_state=7, n_jobs=-1),
                                                        n_comb=100, k=5,
                                                        transformer_X=transformers_X['RF'], transformer_y=transformer_y,
                                                        df_X_train=df_X_train, df_y_train=df_y_train,
                                                        hyperparam_distributions=hyperparam_dist,
                                                        verbose_tqdm=True, verbose_language='en',
                                                        global_seed=7)
                                                        
#df_hyperparam_optimization.to_csv('../reports/tables/hyperparam-optimization_RF.csv')

display_best_hyperparam_combinations(df=df_hyperparam_optimization,
                                     n_best=None, sort_by='n_estimators', ascending=True,
                                     with_one_standard_error_rule=True,
                                     metric_mean_column='auc (mean)',
                                     metric_se_column='auc (se)',
                                     style_format={'max_features':lambda x: ffp(x)})
# Out:
# K-Fold Cross Validation - 1/5: 100%|█████████████████████████████████████████████████| 100/100 [01:56<00:00,  1.17s/it]
# K-Fold Cross Validation - 2/5: 100%|█████████████████████████████████████████████████| 100/100 [04:43<00:00,  2.83s/it]
# K-Fold Cross Validation - 3/5: 100%|█████████████████████████████████████████████████| 100/100 [08:55<00:00,  5.35s/it]
# K-Fold Cross Validation - 4/5: 100%|█████████████████████████████████████████████████| 100/100 [16:37<00:00,  9.97s/it]
# K-Fold Cross Validation - 5/5: 100%|█████████████████████████████████████████████████| 100/100 [32:19<00:00, 19.39s/it]
# <style type="text/css">
# </style>
# <table id="T_fab11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fab11_level0_col0" class="col_heading level0 col0" >n_estimators</th>
#       <th id="T_fab11_level0_col1" class="col_heading level0 col1" >criterion</th>
#       <th id="T_fab11_level0_col2" class="col_heading level0 col2" >max_features</th>
#       <th id="T_fab11_level0_col3" class="col_heading level0 col3" >max_depth</th>
#       <th id="T_fab11_level0_col4" class="col_heading level0 col4" >auc (mean)</th>
#       <th id="T_fab11_level0_col5" class="col_heading level0 col5" >auc (std)</th>
#       <th id="T_fab11_level0_col6" class="col_heading level0 col6" >auc (se)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fab11_level0_row0" class="row_heading level0 row0" >66</th>
#       <td id="T_fab11_row0_col0" class="data row0 col0" >20</td>
#       <td id="T_fab11_row0_col1" class="data row0 col1" >gini</td>
#       <td id="T_fab11_row0_col2" class="data row0 col2" >0.9649709995361269</td>
#       <td id="T_fab11_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_fab11_row0_col4" class="data row0 col4" >0.836087</td>
#       <td id="T_fab11_row0_col5" class="data row0 col5" >0.013742</td>
#       <td id="T_fab11_row0_col6" class="data row0 col6" >0.006146</td>
#     </tr>
#     <tr>
#       <th id="T_fab11_level0_row1" class="row_heading level0 row1" >84</th>
#       <td id="T_fab11_row1_col0" class="data row1 col0" >29</td>
#       <td id="T_fab11_row1_col1" class="data row1 col1" >gini</td>
#       <td id="T_fab11_row1_col2" class="data row1 col2" >0.7963907007825485</td>
#       <td id="T_fab11_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_fab11_row1_col4" class="data row1 col4" >0.838938</td>
#       <td id="T_fab11_row1_col5" class="data row1 col5" >0.012420</td>
#       <td id="T_fab11_row1_col6" class="data row1 col6" >0.005554</td>
#     </tr>
#     <tr>
#       <th id="T_fab11_level0_row2" class="row_heading level0 row2" >46</th>
#       <td id="T_fab11_row2_col0" class="data row2 col0" >48</td>
#       <td id="T_fab11_row2_col1" class="data row2 col1" >gini</td>
#       <td id="T_fab11_row2_col2" class="data row2 col2" >0.4129918291138346</td>
#       <td id="T_fab11_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_fab11_row2_col4" class="data row2 col4" >0.837663</td>
#       <td id="T_fab11_row2_col5" class="data row2 col5" >0.014061</td>
#       <td id="T_fab11_row2_col6" class="data row2 col6" >0.006288</td>
#     </tr>
#     <tr>
#       <th id="T_fab11_level0_row3" class="row_heading level0 row3" >25</th>
#       <td id="T_fab11_row3_col0" class="data row3 col0" >85</td>
#       <td id="T_fab11_row3_col1" class="data row3 col1" >gini</td>
#       <td id="T_fab11_row3_col2" class="data row3 col2" >0.13316944575925016</td>
#       <td id="T_fab11_row3_col3" class="data row3 col3" >6</td>
#       <td id="T_fab11_row3_col4" class="data row3 col4" >0.839375</td>
#       <td id="T_fab11_row3_col5" class="data row3 col5" >0.013998</td>
#       <td id="T_fab11_row3_col6" class="data row3 col6" >0.006260</td>
#     </tr>
#     <tr>
#       <th id="T_fab11_level0_row4" class="row_heading level0 row4" >38</th>
#       <td id="T_fab11_row4_col0" class="data row4 col0" >122</td>
#       <td id="T_fab11_row4_col1" class="data row4 col1" >gini</td>
#       <td id="T_fab11_row4_col2" class="data row4 col2" >0.572625332643954</td>
#       <td id="T_fab11_row4_col3" class="data row4 col3" >8</td>
#       <td id="T_fab11_row4_col4" class="data row4 col4" >0.836204</td>
#       <td id="T_fab11_row4_col5" class="data row4 col5" >0.011821</td>
#       <td id="T_fab11_row4_col6" class="data row4 col6" >0.005287</td>
#     </tr>
#     <tr>
#       <th id="T_fab11_level0_row5" class="row_heading level0 row5" >67</th>
#       <td id="T_fab11_row5_col0" class="data row5 col0" >243</td>
#       <td id="T_fab11_row5_col1" class="data row5 col1" >gini</td>
#       <td id="T_fab11_row5_col2" class="data row5 col2" >0.9450482237927939</td>
#       <td id="T_fab11_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_fab11_row5_col4" class="data row5 col4" >0.840025</td>
#       <td id="T_fab11_row5_col5" class="data row5 col5" >0.011601</td>
#       <td id="T_fab11_row5_col6" class="data row5 col6" >0.005188</td>
#     </tr>
#     <tr>
#       <th id="T_fab11_level0_row6" class="row_heading level0 row6" >63</th>
#       <td id="T_fab11_row6_col0" class="data row6 col0" >262</td>
#       <td id="T_fab11_row6_col1" class="data row6 col1" >gini</td>
#       <td id="T_fab11_row6_col2" class="data row6 col2" >0.30885268486379713</td>
#       <td id="T_fab11_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_fab11_row6_col4" class="data row6 col4" >0.841160</td>
#       <td id="T_fab11_row6_col5" class="data row6 col5" >0.012061</td>
#       <td id="T_fab11_row6_col6" class="data row6 col6" >0.005394</td>
#     </tr>
#     <tr>
#       <th id="T_fab11_level0_row7" class="row_heading level0 row7" >43</th>
#       <td id="T_fab11_row7_col0" class="data row7 col0" >322</td>
#       <td id="T_fab11_row7_col1" class="data row7 col1" >gini</td>
#       <td id="T_fab11_row7_col2" class="data row7 col2" >0.3703510829880352</td>
#       <td id="T_fab11_row7_col3" class="data row7 col3" >4</td>
#       <td id="T_fab11_row7_col4" class="data row7 col4" >0.838361</td>
#       <td id="T_fab11_row7_col5" class="data row7 col5" >0.013479</td>
#       <td id="T_fab11_row7_col6" class="data row7 col6" >0.006028</td>
#     </tr>
#     <tr>
#       <th id="T_fab11_level0_row8" class="row_heading level0 row8" >93</th>
#       <td id="T_fab11_row8_col0" class="data row8 col0" >339</td>
#       <td id="T_fab11_row8_col1" class="data row8 col1" >gini</td>
#       <td id="T_fab11_row8_col2" class="data row8 col2" >0.8756717248700833</td>
#       <td id="T_fab11_row8_col3" class="data row8 col3" >4</td>
#       <td id="T_fab11_row8_col4" class="data row8 col4" >0.837889</td>
#       <td id="T_fab11_row8_col5" class="data row8 col5" >0.013351</td>
#       <td id="T_fab11_row8_col6" class="data row8 col6" >0.005971</td>
#     </tr>
#     <tr>
#       <th id="T_fab11_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_fab11_row9_col0" class="data row9 col0" >358</td>
#       <td id="T_fab11_row9_col1" class="data row9 col1" >gini</td>
#       <td id="T_fab11_row9_col2" class="data row9 col2" >0.07205113335976154</td>
#       <td id="T_fab11_row9_col3" class="data row9 col3" >6</td>
#       <td id="T_fab11_row9_col4" class="data row9 col4" >0.838041</td>
#       <td id="T_fab11_row9_col5" class="data row9 col5" >0.015226</td>
#       <td id="T_fab11_row9_col6" class="data row9 col6" >0.006809</td>
#     </tr>
#     <tr>
#       <th id="T_fab11_level0_row10" class="row_heading level0 row10" >60</th>
#       <td id="T_fab11_row10_col0" class="data row10 col0" >359</td>
#       <td id="T_fab11_row10_col1" class="data row10 col1" >gini</td>
#       <td id="T_fab11_row10_col2" class="data row10 col2" >0.955468323002926</td>
#       <td id="T_fab11_row10_col3" class="data row10 col3" >6</td>
#       <td id="T_fab11_row10_col4" class="data row10 col4" >0.839805</td>
#       <td id="T_fab11_row10_col5" class="data row10 col5" >0.011888</td>
#       <td id="T_fab11_row10_col6" class="data row10 col6" >0.005316</td>
#     </tr>
#     <tr>
#       <th id="T_fab11_level0_row11" class="row_heading level0 row11" >81</th>
#       <td id="T_fab11_row11_col0" class="data row11 col0" >389</td>
#       <td id="T_fab11_row11_col1" class="data row11 col1" >gini</td>
#       <td id="T_fab11_row11_col2" class="data row11 col2" >0.414901772573252</td>
#       <td id="T_fab11_row11_col3" class="data row11 col3" >6</td>
#       <td id="T_fab11_row11_col4" class="data row11 col4" >0.841375</td>
#       <td id="T_fab11_row11_col5" class="data row11 col5" >0.012385</td>
#       <td id="T_fab11_row11_col6" class="data row11 col6" >0.005539</td>
#     </tr>
#     <tr>
#       <th id="T_fab11_level0_row12" class="row_heading level0 row12" >71</th>
#       <td id="T_fab11_row12_col0" class="data row12 col0" >401</td>
#       <td id="T_fab11_row12_col1" class="data row12

# %% [markdown]
# ### Final Training and Evaluation
# ###### **(PT-BR) Treinamento final e Avaliação**

# %%
X_train_transformed = transformers_X['RF'].fit_transform(df_X_train)
X_test_transformed = transformers_X['RF'].transform(df_X_test)
y_train = transformer_y.fit_transform(df_y_train)
y_test  = transformer_y.transform(df_y_test)

# %%
# Combinação de hiperparâmetros nº 66
models['RF'] = RandomForestClassifier(n_estimators=20,
                                      max_features=0.9649709995361269,
                                      criterion='gini',
                                      max_depth=4,
                                      n_jobs=-1,
                                      random_state=7)

train_model(model=models['RF'],
            X=X_train_transformed, y=y_train.reshape(-1),
            display_language='en')
# Out:
# Total Time: 0 s = 0.0 min = 0.0 h
#             0h 00min 00s

# %%
_ = evaluate(
    model=models['RF'],
    X_train=X_train_transformed, X_test=X_test_transformed, y_train=y_train, y_test=y_test,
    beta_fscore=2, threshold=0.5, threshold_step=0.001,
    display_metrics_table=True, plot_confusion_matrix=True, plot_roc_pr_curve=True,
    save_metrics_table=True, save_confusion_matrix=True, save_roc_pr_curve=True,
    path_metrics_table='../reports/tables/model-evaluation_RF.csv',
    path_confusion_matrix='../reports/figures/en/confusion-matrix_RF.png',
    path_roc_pr_curve='../reports/figures/en/roc-pr-curves_RF.png',
    model_title=' - RF', plot_display_language='en')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d5e54">
#   <caption>Evaluation Metrics - RF</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5e54_level0_col0" class="col_heading level0 col0" >Training</th>
#       <th id="T_d5e54_level0_col1" class="col_heading level0 col1" >Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5e54_level0_row0" class="row_heading level0 row0" >Accuracy</th>
#       <td id="T_d5e54_row0_col0" class="data row0 col0" >0.795</td>
#       <td id="T_d5e54_row0_col1" class="data row0 col1" >0.806</td>
#     </tr>
#     <tr>
#       <th id="T_d5e54_level0_row1" class="row_heading level0 row1" >Precision</th>
#       <td id="T_d5e54_row1_col0" class="data row1 col0" >0.674</td>
#       <td id="T_d5e54_row1_col1" class="data row1 col1" >0.696</td>
#     </tr>
#     <tr>
#       <th id="T_d5e54_level0_row2" class="row_heading level0 row2" >Recall</th>
#       <td id="T_d5e54_row2_col0" class="data row2 col0" >0.444</td>
#       <td id="T_d5e54_row2_col1" class="data row2 col1" >0.475</td>
#     </tr>
#     <tr>
#       <th id="T_d5e54_level0_row3" class="row_heading level0 row3" >F1-Score</th>
#       <td id="T_d5e54_row3_col0" class="data row3 col0" >0.535</td>
#       <td id="T_d5e54_row3_col1" class="data row3 col1" >0.565</td>
#     </tr>
#     <tr>
#       <th id="T_d5e54_level0_row4" class="row_heading level0 row4" >F2.-Score</th>
#       <td id="T_d5e54_row4_col0" class="data row4 col0" >0.477</td>
#       <td id="T_d5e54_row4_col1" class="data row4 col1" >0.508</td>
#     </tr>
#     <tr>
#       <th id="T_d5e54_level0_row5" class="row_heading level0 row5" >AUROC</th>
#       <td id="T_d5e54_row5_col0" class="data row5 col0" >-----</td>
#       <td id="T_d5e54_row5_col1" class="data row5 col1" >0.852</td>
#     </tr>
#     <tr>
#       <th id="T_d5e54_level0_row6" class="row_heading level0 row6" >AUPR</th>
#       <td id="T_d5e54_row6_col0" class="data row6 col0" >-----</td>
#       <td id="T_d5e54_row6_col1" class="data row6 col1" >0.676</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Extreme Gradient Boosting (**XGB**)
# ###### **(PT-BR) Máquinas de Gradiente Extremamente Impulsionados**

# %% [markdown]
# ### Hyperparameter Optimization
# ###### **(PT-BR) Otimização de Hiperparâmetros**

# %%
hyperparam_dist = {'n_estimators':stats.randint(100, 1000+1),
                   'learning_rate':stats.uniform(0, 1),
                   'max_depth':stats.randint(0, 10+1),
                   'reg_lambda':stats.loguniform(10**-5, 10**2)}

df_hyperparam_optimization = random_search_with_kfoldcv(model=XGBClassifier(objective='binary:logistic', random_state=7, n_jobs=-1),
                                                        n_comb=1000, k=5,
                                                        transformer_X=transformers_X['XGB'], transformer_y=transformer_y,
                                                        df_X_train=df_X_train, df_y_train=df_y_train,
                                                        hyperparam_distributions=hyperparam_dist,
                                                        verbose_tqdm=True, verbose_language='en',
                                                        global_seed=7)
                                                        
df_hyperparam_optimization.to_csv('../reports/tables/hyperparam-optimization_XGB.csv')

display_best_hyperparam_combinations(df=df_hyperparam_optimization,
                                     n_best=None, sort_by='n_estimators', ascending=True,
                                     with_one_standard_error_rule=True,
                                     metric_mean_column='auc (mean)',
                                     metric_se_column='auc (se)',
                                     style_format={'learning_rate':lambda x: ffp(x), 'reg_lambda':lambda x: ffp(x)})
# Out:
# K-Fold Cross Validation - 1/5: 100%|██████████| 1000/1000 [10:54<00:00,  1.53it/s]
# K-Fold Cross Validation - 2/5: 100%|██████████| 1000/1000 [10:41<00:00,  1.56it/s]
# K-Fold Cross Validation - 3/5: 100%|██████████| 1000/1000 [10:39<00:00,  1.56it/s]
# K-Fold Cross Validation - 4/5: 100%|██████████| 1000/1000 [10:37<00:00,  1.57it/s]
# K-Fold Cross Validation - 5/5: 100%|██████████| 1000/1000 [11:07<00:00,  1.50it/s]
# <style type="text/css">
# </style>
# <table id="T_73803">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73803_level0_col0" class="col_heading level0 col0" >n_estimators</th>
#       <th id="T_73803_level0_col1" class="col_heading level0 col1" >learning_rate</th>
#       <th id="T_73803_level0_col2" class="col_heading level0 col2" >max_depth</th>
#       <th id="T_73803_level0_col3" class="col_heading level0 col3" >reg_lambda</th>
#       <th id="T_73803_level0_col4" class="col_heading level0 col4" >auc (mean)</th>
#       <th id="T_73803_level0_col5" class="col_heading level0 col5" >auc (std)</th>
#       <th id="T_73803_level0_col6" class="col_heading level0 col6" >auc (se)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73803_level0_row0" class="row_heading level0 row0" >695</th>
#       <td id="T_73803_row0_col0" class="data row0 col0" >100</td>
#       <td id="T_73803_row0_col1" class="data row0 col1" >0.9223280085419</td>
#       <td id="T_73803_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_73803_row0_col3" class="data row0 col3" >28.595392351791165</td>
#       <td id="T_73803_row0_col4" class="data row0 col4" >0.844648</td>
#       <td id="T_73803_row0_col5" class="data row0 col5" >0.013413</td>
#       <td id="T_73803_row0_col6" class="data row0 col6" >0.005999</td>
#     </tr>
#     <tr>
#       <th id="T_73803_level0_row1" class="row_heading level0 row1" >239</th>
#       <td id="T_73803_row1_col0" class="data row1 col0" >108</td>
#       <td id="T_73803_row1_col1" class="data row1 col1" >0.2585894985926458</td>
#       <td id="T_73803_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_73803_row1_col3" class="data row1 col3" >0.0006458423060125868</td>
#       <td id="T_73803_row1_col4" class="data row1 col4" >0.844708</td>
#       <td id="T_73803_row1_col5" class="data row1 col5" >0.012600</td>
#       <td id="T_73803_row1_col6" class="data row1 col6" >0.005635</td>
#     </tr>
#     <tr>
#       <th id="T_73803_level0_row2" class="row_heading level0 row2" >618</th>
#       <td id="T_73803_row2_col0" class="data row2 col0" >114</td>
#       <td id="T_73803_row2_col1" class="data row2 col1" >0.04324792766058927</td>
#       <td id="T_73803_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_73803_row2_col3" class="data row2 col3" >0.00002007869550320032</td>
#       <td id="T_73803_row2_col4" class="data row2 col4" >0.843760</td>
#       <td id="T_73803_row2_col5" class="data row2 col5" >0.012263</td>
#       <td id="T_73803_row2_col6" class="data row2 col6" >0.005484</td>
#     </tr>
#     <tr>
#       <th id="T_73803_level0_row3" class="row_heading level0 row3" >581</th>
#       <td id="T_73803_row3_col0" class="data row3 col0" >128</td>
#       <td id="T_73803_row3_col1" class="data row3 col1" >0.7898859590776569</td>
#       <td id="T_73803_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_73803_row3_col3" class="data row3 col3" >3.3822189114853245</td>
#       <td id="T_73803_row3_col4" class="data row3 col4" >0.843585</td>
#       <td id="T_73803_row3_col5" class="data row3 col5" >0.012915</td>
#       <td id="T_73803_row3_col6" class="data row3 col6" >0.005776</td>
#     </tr>
#     <tr>
#       <th id="T_73803_level0_row4" class="row_heading level0 row4" >756</th>
#       <td id="T_73803_row4_col0" class="data row4 col0" >132</td>
#       <td id="T_73803_row4_col1" class="data row4 col1" >0.15785275580853553</td>
#       <td id="T_73803_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_73803_row4_col3" class="data row4 col3" >0.0001273413033690729</td>
#       <td id="T_73803_row4_col4" class="data row4 col4" >0.844646</td>
#       <td id="T_73803_row4_col5" class="data row4 col5" >0.012118</td>
#       <td id="T_73803_row4_col6" class="data row4 col6" >0.005419</td>
#     </tr>
#     <tr>
#       <th id="T_73803_level0_row5" class="row_heading level0 row5" >703</th>
#       <td id="T_73803_row5_col0" class="data row5 col0" >144</td>
#       <td id="T_73803_row5_col1" class="data row5 col1" >0.5513195121573071</td>
#       <td id="T_73803_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_73803_row5_col3" class="data row5 col3" >0.07231636450127694</td>
#       <td id="T_73803_row5_col4" class="data row5 col4" >0.842992</td>
#       <td id="T_73803_row5_col5" class="data row5 col5" >0.012534</td>
#       <td id="T_73803_row5_col6" class="data row5 col6" >0.005605</td>
#     </tr>
#     <tr>
#       <th id="T_73803_level0_row6" class="row_heading level0 row6" >775</th>
#       <td id="T_73803_row6_col0" class="data row6 col0" >152</td>
#       <td id="T_73803_row6_col1" class="data row6 col1" >0.5074292852031799</td>
#       <td id="T_73803_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_73803_row6_col3" class="data row6 col3" >0.03564552343087015</td>
#       <td id="T_73803_row6_col4" class="data row6 col4" >0.843649</td>
#       <td id="T_73803_row6_col5" class="data row6 col5" >0.012717</td>
#       <td id="T_73803_row6_col6" class="data row6 col6" >0.005687</td>
#     </tr>
#     <tr>
#       <th id="T_73803_level0_row7" class="row_heading level0 row7" >831</th>
#       <td id="T_73803_row7_col0" class="data row7 col0" >152</td>
#       <td id="T_73803_row7_col1" class="data row7 col1" >0.26035696480621595</td>
#       <td id="T_73803_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_73803_row7_col3" class="data row7 col3" >0.0006645057658785729</td>
#       <td id="T_73803_row7_col4" class="data row7 col4" >0.844406</td>
#       <td id="T_73803_row7_col5" class="data row7 col5" >0.012536</td>
#       <td id="T_73803_row7_col6" class="data row7 col6" >0.005606</td>
#     </tr>
#     <tr>
#       <th id="T_73803_level0_row8" class="row_heading level0 row8" >293</th>
#       <td id="T_73803_row8_col0" class="data row8 col0" >167</td>
#       <td id="T_73803_row8_col1" class="data row8 col1" >0.047013165032900206</td>
#       <td id="T_73803_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_73803_row8_col3" class="data row8 col3" >0.00002133497583191039</td>
#       <td id="T_73803_row8_col4" class="data row8 col4" >0.840121</td>
#       <td id="T_73803_row8_col5" class="data row8 col5" >0.012899</td>
#       <td id="T_73803_row8_col6" class="data row8 col6" >0.005768</td>
#     </tr>
#     <tr>
#       <th id="T_73803_level0_row9" class="row_heading level0 row9" >188</th>
#       <td id="T_73803_row9_col0" class="data row9 col0" >176</td>
#       <td id="T_73803_row9_col1" class="data row9 col1" >0.9187092051422681</td>
#       <td id="T_73803_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_73803_row9_col3" class="data row9 col3" >26.975185259124093</td>
#       <td id="T_73803_row9_col4" class="data row9 col4" >0.843827</td>
#       <td id="T_73803_row9_col5" class="data row9 col5" >0.013590</td>
#       <td id="T_73803_row9_col6" class="data row9 col6" >0.006078</td>
#     </tr>
#     <tr>
#       <th id="T_73803_level0_row10" class="row_heading level0 row10" >440</th>
#       <td id="T_73803_row10_col0" class="data row10 col0" >184</td>
#       <td id="T_73803_row10_col1" class="data row10 col1" >0.21674199029017294</td>
#       <td id="T_73803_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_73803_row10_col3" class="data row10 col3" >0.00032899851072063695</td>
#       <td id="T_73803_row10_col4" class="data row10 col4" >0.844664</td>
#       <td id="T_73803_row10_col5" class="data row10 col5" >0.012443</td>
#       <td id="T_73803_row10_col6" class="data row10 col6" >0.005565</td>
#     </tr>
#     <tr>
#       <th id="T_73803_level0_row11" class="row_heading level0 row11" >280</th>
#       <td id="T_73803_row11_col0" class="data row11 col0" >192</td>
#       <td id="T_73803_row11_col1" class="data row11 col1" >0.13486463139689686</td>
#       <td id="T_73803_row11_col2" class="data row11 col2" >2</td>
#       <td id="T_73803_row11_col3" class="data row11 col3" >0.00008791286221311042</td>
#       <td id="T_73803_row11_col4" class="data row11 col4" >0.839963</td>
#       <td id="T_73803_row11_col5" class="data row11 col5" >0.012116</td>
#       <td id="T_73803_row11_col6" class="data row11 col6" >0.005418</td

# %% [markdown]
# ### Final Training and Evaluation
# ###### **(PT-BR) Treinamento final e Avaliação**

# %%
X_train_transformed = transformers_X['XGB'].fit_transform(df_X_train)
X_test_transformed = transformers_X['XGB'].transform(df_X_test)
y_train = transformer_y.fit_transform(df_y_train)
y_test  = transformer_y.transform(df_y_test)

# %%
models['XGB'] = XGBClassifier(n_estimators=100,
                              max_depth=1,
                              learning_rate=0.9223280085419,
                              reg_lambda=28.595392351791165,
                              objective='binary:logistic',
                              n_jobs=-1,
                              random_state=7)

train_model(model=models['XGB'],
            X=X_train_transformed, y=y_train.reshape(-1),
            display_language='en')
# Out:
# Total Time: 0 s = 0.0 min = 0.0 h
#             0h 00min 00s

# %%
_ = evaluate(
    model=models['XGB'],
    X_train=X_train_transformed, X_test=X_test_transformed, y_train=y_train, y_test=y_test,
    beta_fscore=2, threshold=0.5, threshold_step=0.001,
    display_metrics_table=True, plot_confusion_matrix=True, plot_roc_pr_curve=True,
    save_metrics_table=True, save_confusion_matrix=True, save_roc_pr_curve=True,
    path_metrics_table='../reports/tables/model-evaluation_XGB.csv',
    path_confusion_matrix='../reports/figures/en/confusion-matrix_XGB.png',
    path_roc_pr_curve='../reports/figures/en/roc-pr-curves_XGB.png',
    model_title=' - XGB', plot_display_language='en')
# Out:
# <style type="text/css">
# </style>
# <table id="T_cb861">
#   <caption>Evaluation Metrics - XGB</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb861_level0_col0" class="col_heading level0 col0" >Training</th>
#       <th id="T_cb861_level0_col1" class="col_heading level0 col1" >Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb861_level0_row0" class="row_heading level0 row0" >Accuracy</th>
#       <td id="T_cb861_row0_col0" class="data row0 col0" >0.810</td>
#       <td id="T_cb861_row0_col1" class="data row0 col1" >0.813</td>
#     </tr>
#     <tr>
#       <th id="T_cb861_level0_row1" class="row_heading level0 row1" >Precision</th>
#       <td id="T_cb861_row1_col0" class="data row1 col0" >0.680</td>
#       <td id="T_cb861_row1_col1" class="data row1 col1" >0.684</td>
#     </tr>
#     <tr>
#       <th id="T_cb861_level0_row2" class="row_heading level0 row2" >Recall</th>
#       <td id="T_cb861_row2_col0" class="data row2 col0" >0.539</td>
#       <td id="T_cb861_row2_col1" class="data row2 col1" >0.550</td>
#     </tr>
#     <tr>
#       <th id="T_cb861_level0_row3" class="row_heading level0 row3" >F1-Score</th>
#       <td id="T_cb861_row3_col0" class="data row3 col0" >0.601</td>
#       <td id="T_cb861_row3_col1" class="data row3 col1" >0.610</td>
#     </tr>
#     <tr>
#       <th id="T_cb861_level0_row4" class="row_heading level0 row4" >F2.-Score</th>
#       <td id="T_cb861_row4_col0" class="data row4 col0" >0.562</td>
#       <td id="T_cb861_row4_col1" class="data row4 col1" >0.573</td>
#     </tr>
#     <tr>
#       <th id="T_cb861_level0_row5" class="row_heading level0 row5" >AUROC</th>
#       <td id="T_cb861_row5_col0" class="data row5 col0" >-----</td>
#       <td id="T_cb861_row5_col1" class="data row5 col1" >0.860</td>
#     </tr>
#     <tr>
#       <th id="T_cb861_level0_row6" class="row_heading level0 row6" >AUPR</th>
#       <td id="T_cb861_row6_col0" class="data row6 col0" >-----</td>
#       <td id="T_cb861_row6_col1" class="data row6 col1" >0.687</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## K-Nearest Neighbors (**KNN**)
# ###### **(PT-BR) K-Vizinhos mais Próximos**

# %% [markdown]
# ### Hyperparameter Optimization
# ###### **(PT-BR) Otimização de Hiperparâmetros**

# %%
hyperparam_dist = {'n_neighbors':stats.randint(1, 200+1),
                   'weights':['uniform', 'distance'],
                   'p':stats.randint(1, 5+1)}

df_hyperparam_optimization = parallelized_random_search_with_kfoldcv(model=KNeighborsClassifier(metric='minkowski'),
                                                                     n_comb=1000, k=5,
                                                                     transformer_X=transformers_X['KNN'], transformer_y=transformer_y,
                                                                     df_X_train=df_X_train, df_y_train=df_y_train,
                                                                     hyperparam_distributions=hyperparam_dist,
                                                                     n_jobs=5,
                                                                     global_seed=7,
                                                                     display_language='en')
                                                                     
df_hyperparam_optimization.to_csv('../reports/tables/hyperparam-optimization_KNN.csv')

display_best_hyperparam_combinations(df=df_hyperparam_optimization,
                                     n_best=10, sort_by='n_neighbors', ascending=True,
                                     with_one_standard_error_rule=True,
                                     metric_mean_column='auc (mean)',
                                     metric_se_column='auc (se)',
                                     style_format={})
# Out:
# Total Time: 1120 s = 18.7 min = 0.3 h
#             0h 18min 40s
# <style type="text/css">
# </style>
# <table id="T_dafae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dafae_level0_col0" class="col_heading level0 col0" >n_neighbors</th>
#       <th id="T_dafae_level0_col1" class="col_heading level0 col1" >weights</th>
#       <th id="T_dafae_level0_col2" class="col_heading level0 col2" >p</th>
#       <th id="T_dafae_level0_col3" class="col_heading level0 col3" >auc (mean)</th>
#       <th id="T_dafae_level0_col4" class="col_heading level0 col4" >auc (std)</th>
#       <th id="T_dafae_level0_col5" class="col_heading level0 col5" >auc (se)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dafae_level0_row0" class="row_heading level0 row0" >922</th>
#       <td id="T_dafae_row0_col0" class="data row0 col0" >24</td>
#       <td id="T_dafae_row0_col1" class="data row0 col1" >uniform</td>
#       <td id="T_dafae_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_dafae_row0_col3" class="data row0 col3" >0.824958</td>
#       <td id="T_dafae_row0_col4" class="data row0 col4" >0.012409</td>
#       <td id="T_dafae_row0_col5" class="data row0 col5" >0.005550</td>
#     </tr>
#     <tr>
#       <th id="T_dafae_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_dafae_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_dafae_row1_col1" class="data row1 col1" >uniform</td>
#       <td id="T_dafae_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_dafae_row1_col3" class="data row1 col3" >0.824958</td>
#       <td id="T_dafae_row1_col4" class="data row1 col4" >0.012409</td>
#       <td id="T_dafae_row1_col5" class="data row1 col5" >0.005550</td>
#     </tr>
#     <tr>
#       <th id="T_dafae_level0_row2" class="row_heading level0 row2" >584</th>
#       <td id="T_dafae_row2_col0" class="data row2 col0" >25</td>
#       <td id="T_dafae_row2_col1" class="data row2 col1" >uniform</td>
#       <td id="T_dafae_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_dafae_row2_col3" class="data row2 col3" >0.824960</td>
#       <td id="T_dafae_row2_col4" class="data row2 col4" >0.012772</td>
#       <td id="T_dafae_row2_col5" class="data row2 col5" >0.005712</td>
#     </tr>
#     <tr>
#       <th id="T_dafae_level0_row3" class="row_heading level0 row3" >543</th>
#       <td id="T_dafae_row3_col0" class="data row3 col0" >26</td>
#       <td id="T_dafae_row3_col1" class="data row3 col1" >uniform</td>
#       <td id="T_dafae_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_dafae_row3_col3" class="data row3 col3" >0.825402</td>
#       <td id="T_dafae_row3_col4" class="data row3 col4" >0.010915</td>
#       <td id="T_dafae_row3_col5" class="data row3 col5" >0.004881</td>
#     </tr>
#     <tr>
#       <th id="T_dafae_level0_row4" class="row_heading level0 row4" >437</th>
#       <td id="T_dafae_row4_col0" class="data row4 col0" >27</td>
#       <td id="T_dafae_row4_col1" class="data row4 col1" >uniform</td>
#       <td id="T_dafae_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_dafae_row4_col3" class="data row4 col3" >0.825323</td>
#       <td id="T_dafae_row4_col4" class="data row4 col4" >0.012829</td>
#       <td id="T_dafae_row4_col5" class="data row4 col5" >0.005737</td>
#     </tr>
#     <tr>
#       <th id="T_dafae_level0_row5" class="row_heading level0 row5" >656</th>
#       <td id="T_dafae_row5_col0" class="data row5 col0" >27</td>
#       <td id="T_dafae_row5_col1" class="data row5 col1" >uniform</td>
#       <td id="T_dafae_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_dafae_row5_col3" class="data row5 col3" >0.825474</td>
#       <td id="T_dafae_row5_col4" class="data row5 col4" >0.013194</td>
#       <td id="T_dafae_row5_col5" class="data row5 col5" >0.005900</td>
#     </tr>
#     <tr>
#       <th id="T_dafae_level0_row6" class="row_heading level0 row6" >129</th>
#       <td id="T_dafae_row6_col0" class="data row6 col0" >27</td>
#       <td id="T_dafae_row6_col1" class="data row6 col1" >uniform</td>
#       <td id="T_dafae_row6_col2" class="data row6 col2" >5</td>
#       <td id="T_dafae_row6_col3" class="data row6 col3" >0.825761</td>
#       <td id="T_dafae_row6_col4" class="data row6 col4" >0.011015</td>
#       <td id="T_dafae_row6_col5" class="data row6 col5" >0.004926</td>
#     </tr>
#     <tr>
#       <th id="T_dafae_level0_row7" class="row_heading level0 row7" >789</th>
#       <td id="T_dafae_row7_col0" class="data row7 col0" >28</td>
#       <td id="T_dafae_row7_col1" class="data row7 col1" >uniform</td>
#       <td id="T_dafae_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_dafae_row7_col3" class="data row7 col3" >0.825351</td>
#       <td id="T_dafae_row7_col4" class="data row7 col4" >0.013385</td>
#       <td id="T_dafae_row7_col5" class="data row7 col5" >0.005986</td>
#     </tr>
#     <tr>
#       <th id="T_dafae_level0_row8" class="row_heading level0 row8" >527</th>
#       <td id="T_dafae_row8_col0" class="data row8 col0" >29</td>
#       <td id="T_dafae_row8_col1" class="data row8 col1" >uniform</td>
#       <td id="T_dafae_row8_col2" class="data row8 col2" >5</td>
#       <td id="T_dafae_row8_col3" class="data row8 col3" >0.825991</td>
#       <td id="T_dafae_row8_col4" class="data row8 col4" >0.011473</td>
#       <td id="T_dafae_row8_col5" class="data row8 col5" >0.005131</td>
#     </tr>
#     <tr>
#       <th id="T_dafae_level0_row9" class="row_heading level0 row9" >406</th>
#       <td id="T_dafae_row9_col0" class="data row9 col0" >29</td>
#       <td id="T_dafae_row9_col1" class="data row9 col1" >uniform</td>
#       <td id="T_dafae_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_dafae_row9_col3" class="data row9 col3" >0.825806</td>
#       <td id="T_dafae_row9_col4" class="data row9 col4" >0.013680</td>
#       <td id="T_dafae_row9_col5" class="data row9 col5" >0.006118</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Final Training and Evaluation
# ###### **(PT-BR) Treinamento final e Avaliação**

# %%
X_train_transformed = transformers_X['KNN'].fit_transform(df_X_train)
X_test_transformed = transformers_X['KNN'].transform(df_X_test)
y_train = transformer_y.fit_transform(df_y_train)
y_test  = transformer_y.transform(df_y_test)

# %%
# Combinação nº 9 de hiperparâmetros
models['KNN'] = KNeighborsClassifier(n_neighbors=24,
                                     weights='uniform',
                                     p=3,
                                     metric='minkowski',
                                     n_jobs=-1)

train_model(model=models['KNN'],
            X=X_train_transformed, y=y_train.reshape(-1),
            display_language='en')
# Out:
# Total Time: 0 s = 0.0 min = 0.0 h
#             0h 00min 00s

# %%
_ = evaluate(
    model=models['KNN'],
    X_train=X_train_transformed, X_test=X_test_transformed, y_train=y_train, y_test=y_test,
    beta_fscore=2, threshold=0.5, threshold_step=0.001,
    display_metrics_table=True, plot_confusion_matrix=True, plot_roc_pr_curve=True,
    save_metrics_table=True, save_confusion_matrix=True, save_roc_pr_curve=True,
    path_metrics_table='../reports/tables/model-evaluation_KNN.csv',
    path_confusion_matrix='../reports/figures/en/confusion-matrix_KNN.png',
    path_roc_pr_curve='../reports/figures/en/roc-pr-curves_KNN.png',
    model_title=' - KNN', plot_display_language='en')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c86eb">
#   <caption>Evaluation Metrics - KNN</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c86eb_level0_col0" class="col_heading level0 col0" >Training</th>
#       <th id="T_c86eb_level0_col1" class="col_heading level0 col1" >Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c86eb_level0_row0" class="row_heading level0 row0" >Accuracy</th>
#       <td id="T_c86eb_row0_col0" class="data row0 col0" >0.801</td>
#       <td id="T_c86eb_row0_col1" class="data row0 col1" >0.802</td>
#     </tr>
#     <tr>
#       <th id="T_c86eb_level0_row1" class="row_heading level0 row1" >Precision</th>
#       <td id="T_c86eb_row1_col0" class="data row1 col0" >0.629</td>
#       <td id="T_c86eb_row1_col1" class="data row1 col1" >0.626</td>
#     </tr>
#     <tr>
#       <th id="T_c86eb_level0_row2" class="row_heading level0 row2" >Recall</th>
#       <td id="T_c86eb_row2_col0" class="data row2 col0" >0.613</td>
#       <td id="T_c86eb_row2_col1" class="data row2 col1" >0.630</td>
#     </tr>
#     <tr>
#       <th id="T_c86eb_level0_row3" class="row_heading level0 row3" >F1-Score</th>
#       <td id="T_c86eb_row3_col0" class="data row3 col0" >0.621</td>
#       <td id="T_c86eb_row3_col1" class="data row3 col1" >0.628</td>
#     </tr>
#     <tr>
#       <th id="T_c86eb_level0_row4" class="row_heading level0 row4" >F2.-Score</th>
#       <td id="T_c86eb_row4_col0" class="data row4 col0" >0.616</td>
#       <td id="T_c86eb_row4_col1" class="data row4 col1" >0.629</td>
#     </tr>
#     <tr>
#       <th id="T_c86eb_level0_row5" class="row_heading level0 row5" >AUROC</th>
#       <td id="T_c86eb_row5_col0" class="data row5 col0" >-----</td>
#       <td id="T_c86eb_row5_col1" class="data row5 col1" >0.841</td>
#     </tr>
#     <tr>
#       <th id="T_c86eb_level0_row6" class="row_heading level0 row6" >AUPR</th>
#       <td id="T_c86eb_row6_col0" class="data row6 col0" >-----</td>
#       <td id="T_c86eb_row6_col1" class="data row6 col1" >0.632</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Support Vector Machines (**SVM**)
# ###### **(PT-BR) Máquinas de Vetores de Suporte**

# %% [markdown]
# ### Hyperparameter Optimization
# ###### **(PT-BR) Otimização de Hiperparâmetros**

# %%
hyperparam_dist = {'C':stats.loguniform(2**-10, 2**10),
                   'gamma':stats.loguniform(2**-20, 2**5)}

df_hyperparam_optimization = parallelized_random_search_with_kfoldcv(model=SVC(random_state=7, kernel='rbf', probability=True),
                                                                     n_comb=100, k=5,
                                                                     transformer_X=transformers_X['SVM'], transformer_y=transformer_y,
                                                                     df_X_train=df_X_train, df_y_train=df_y_train,
                                                                     hyperparam_distributions=hyperparam_dist,
                                                                     n_jobs=5,
                                                                     global_seed=7,
                                                                     display_language='en')
                                                                     
df_hyperparam_optimization.to_csv('../reports/tables/hyperparam-optimization_SVM.csv')

display_best_hyperparam_combinations(df=df_hyperparam_optimization,
                                     n_best=10, sort_by=None, ascending=False,
                                     with_one_standard_error_rule=False,
                                     metric_mean_column='auc (mean)',
                                     metric_se_column='auc (se)',
                                     style_format={'C':lambda x:ffp(x), 'gamma':lambda x:ffp(x)})
# Out:
# Total Time: 1045 s = 17.4 min = 0.3 h
#             0h 17min 25s
# <style type="text/css">
# </style>
# <table id="T_2671a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2671a_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_2671a_level0_col1" class="col_heading level0 col1" >gamma</th>
#       <th id="T_2671a_level0_col2" class="col_heading level0 col2" >auc (mean)</th>
#       <th id="T_2671a_level0_col3" class="col_heading level0 col3" >auc (std)</th>
#       <th id="T_2671a_level0_col4" class="col_heading level0 col4" >auc (se)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2671a_level0_row0" class="row_heading level0 row0" >80</th>
#       <td id="T_2671a_row0_col0" class="data row0 col0" >0.0096854044419903</td>
#       <td id="T_2671a_row0_col1" class="data row0 col1" >0.00001678503431063868</td>
#       <td id="T_2671a_row0_col2" class="data row0 col2" >0.831205</td>
#       <td id="T_2671a_row0_col3" class="data row0 col3" >0.019588</td>
#       <td id="T_2671a_row0_col4" class="data row0 col4" >0.008760</td>
#     </tr>
#     <tr>
#       <th id="T_2671a_level0_row1" class="row_heading level0 row1" >56</th>
#       <td id="T_2671a_row1_col0" class="data row1 col0" >0.003508930082791</td>
#       <td id="T_2671a_row1_col1" class="data row1 col1" >0.000004717842365609852</td>
#       <td id="T_2671a_row1_col2" class="data row1 col2" >0.831203</td>
#       <td id="T_2671a_row1_col3" class="data row1 col3" >0.019377</td>
#       <td id="T_2671a_row1_col4" class="data row1 col4" >0.008666</td>
#     </tr>
#     <tr>
#       <th id="T_2671a_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_2671a_row2_col0" class="data row2 col0" >0.002651496698028</td>
#       <td id="T_2671a_row2_col1" class="data row2 col1" >0.0000033238307076191213</td>
#       <td id="T_2671a_row2_col2" class="data row2 col2" >0.831201</td>
#       <td id="T_2671a_row2_col3" class="data row2 col3" >0.019271</td>
#       <td id="T_2671a_row2_col4" class="data row2 col4" >0.008618</td>
#     </tr>
#     <tr>
#       <th id="T_2671a_level0_row3" class="row_heading level0 row3" >48</th>
#       <td id="T_2671a_row3_col0" class="data row3 col0" >0.0119159053883837</td>
#       <td id="T_2671a_row3_col1" class="data row3 col1" >0.00002174872692658874</td>
#       <td id="T_2671a_row3_col2" class="data row3 col2" >0.831199</td>
#       <td id="T_2671a_row3_col3" class="data row3 col3" >0.019265</td>
#       <td id="T_2671a_row3_col4" class="data row3 col4" >0.008616</td>
#     </tr>
#     <tr>
#       <th id="T_2671a_level0_row4" class="row_heading level0 row4" >55</th>
#       <td id="T_2671a_row4_col0" class="data row4 col0" >0.0009960719731237</td>
#       <td id="T_2671a_row4_col1" class="data row4 col1" >0.000000977548768559336</td>
#       <td id="T_2671a_row4_col2" class="data row4 col2" >0.831169</td>
#       <td id="T_2671a_row4_col3" class="data row4 col3" >0.019503</td>
#       <td id="T_2671a_row4_col4" class="data row4 col4" >0.008722</td>
#     </tr>
#     <tr>
#       <th id="T_2671a_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_2671a_row5_col0" class="data row5 col0" >0.0028126890584144</td>
#       <td id="T_2671a_row5_col1" class="data row5 col1" >0.0000035783036151318345</td>
#       <td id="T_2671a_row5_col2" class="data row5 col2" >0.831123</td>
#       <td id="T_2671a_row5_col3" class="data row5 col3" >0.019511</td>
#       <td id="T_2671a_row5_col4" class="data row5 col4" >0.008726</td>
#     </tr>
#     <tr>
#       <th id="T_2671a_level0_row6" class="row_heading level0 row6" >71</th>
#       <td id="T_2671a_row6_col0" class="data row6 col0" >0.0060126339578758</td>
#       <td id="T_2671a_row6_col1" class="data row6 col1" >0.000009249238731931034</td>
#       <td id="T_2671a_row6_col2" class="data row6 col2" >0.831092</td>
#       <td id="T_2671a_row6_col3" class="data row6 col3" >0.019365</td>
#       <td id="T_2671a_row6_col4" class="data row6 col4" >0.008660</td>
#     </tr>
#     <tr>
#       <th id="T_2671a_level0_row7" class="row_heading level0 row7" >30</th>
#       <td id="T_2671a_row7_col0" class="data row7 col0" >0.0167114624961116</td>
#       <td id="T_2671a_row7_col1" class="data row7 col1" >0.00003319274013141588</td>
#       <td id="T_2671a_row7_col2" class="data row7 col2" >0.831090</td>
#       <td id="T_2671a_row7_col3" class="data row7 col3" >0.019495</td>
#       <td id="T_2671a_row7_col4" class="data row7 col4" >0.008718</td>
#     </tr>
#     <tr>
#       <th id="T_2671a_level0_row8" class="row_heading level0 row8" >92</th>
#       <td id="T_2671a_row8_col0" class="data row8 col0" >0.0017158226880264</td>
#       <td id="T_2671a_row8_col1" class="data row8 col1" >0.00000192914796952792</td>
#       <td id="T_2671a_row8_col2" class="data row8 col2" >0.831082</td>
#       <td id="T_2671a_row8_col3" class="data row8 col3" >0.019418</td>
#       <td id="T_2671a_row8_col4" class="data row8 col4" >0.008684</td>
#     </tr>
#     <tr>
#       <th id="T_2671a_level0_row9" class="row_heading level0 row9" >76</th>
#       <td id="T_2671a_row9_col0" class="data row9 col0" >0.0065129297278917</td>
#       <td id="T_2671a_row9_col1" class="data row9 col1" >0.000010221050238172716</td>
#       <td id="T_2671a_row9_col2" class="data row9 col2" >0.831036</td>
#       <td id="T_2671a_row9_col3" class="data row9 col3" >0.019403</td>
#       <td id="T_2671a_row9_col4" class="data row9 col4" >0.008677</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Final Training and Evaluation
# ###### **(PT-BR) Treinamento final e Avaliação**

# %%
X_train_transformed = transformers_X['SVM'].fit_transform(df_X_train)
X_test_transformed = transformers_X['SVM'].transform(df_X_test)
y_train = transformer_y.fit_transform(df_y_train)
y_test  = transformer_y.transform(df_y_test)

# %%
# Combinação nº 80 de hiperparâmetros
models['SVM'] = SVC(C=0.009685404441990337,
                    gamma=0.00001678503431063868,
                    kernel='rbf',
                    probability=True,
                    random_state=7)

train_model(model=models['SVM'],
            X=X_train_transformed, y=y_train.reshape(-1),
            display_language='en')
# Out:
# Total Time: 4 s = 0.1 min = 0.0 h
#             0h 00min 04s

# %%
_ = evaluate(
    model=models['SVM'],
    X_train=X_train_transformed, X_test=X_test_transformed, y_train=y_train, y_test=y_test,
    beta_fscore=2, threshold=0.5, threshold_step=0.001,
    display_metrics_table=True, plot_confusion_matrix=True, plot_roc_pr_curve=True,
    save_metrics_table=True, save_confusion_matrix=True, save_roc_pr_curve=True,
    path_metrics_table='../reports/tables/model-evaluation_SVM.csv',
    path_confusion_matrix='../reports/figures/en/confusion-matrix_SVM.png',
    path_roc_pr_curve='../reports/figures/en/roc-pr-curves_SVM.png',
    model_title=' - SVM', plot_display_language='en')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1e88c">
#   <caption>Evaluation Metrics - SVM</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e88c_level0_col0" class="col_heading level0 col0" >Training</th>
#       <th id="T_1e88c_level0_col1" class="col_heading level0 col1" >Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e88c_level0_row0" class="row_heading level0 row0" >Accuracy</th>
#       <td id="T_1e88c_row0_col0" class="data row0 col0" >0.791</td>
#       <td id="T_1e88c_row0_col1" class="data row0 col1" >0.798</td>
#     </tr>
#     <tr>
#       <th id="T_1e88c_level0_row1" class="row_heading level0 row1" >Precision</th>
#       <td id="T_1e88c_row1_col0" class="data row1 col0" >0.614</td>
#       <td id="T_1e88c_row1_col1" class="data row1 col1" >0.628</td>
#     </tr>
#     <tr>
#       <th id="T_1e88c_level0_row2" class="row_heading level0 row2" >Recall</th>
#       <td id="T_1e88c_row2_col0" class="data row2 col0" >0.572</td>
#       <td id="T_1e88c_row2_col1" class="data row2 col1" >0.585</td>
#     </tr>
#     <tr>
#       <th id="T_1e88c_level0_row3" class="row_heading level0 row3" >F1-Score</th>
#       <td id="T_1e88c_row3_col0" class="data row3 col0" >0.592</td>
#       <td id="T_1e88c_row3_col1" class="data row3 col1" >0.605</td>
#     </tr>
#     <tr>
#       <th id="T_1e88c_level0_row4" class="row_heading level0 row4" >F2.-Score</th>
#       <td id="T_1e88c_row4_col0" class="data row4 col0" >0.580</td>
#       <td id="T_1e88c_row4_col1" class="data row4 col1" >0.593</td>
#     </tr>
#     <tr>
#       <th id="T_1e88c_level0_row5" class="row_heading level0 row5" >AUROC</th>
#       <td id="T_1e88c_row5_col0" class="data row5 col0" >-----</td>
#       <td id="T_1e88c_row5_col1" class="data row5 col1" >0.846</td>
#     </tr>
#     <tr>
#       <th id="T_1e88c_level0_row6" class="row_heading level0 row6" >AUPR</th>
#       <td id="T_1e88c_row6_col0" class="data row6 col0" >-----</td>
#       <td id="T_1e88c_row6_col1" class="data row6 col1" >0.665</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Saving and Loading Trained Models
# ###### **(PT-BR) Salvando e Carregando os Modelos Treinados**

# %%
save_models(models_dict=models, path='../models/', format='.pkl')

# %%
models = load_models(models_names=['LR', 'DT', 'KNN', 'RF', 'SVM', 'XGB'], path='../models/', format='.pkl')
