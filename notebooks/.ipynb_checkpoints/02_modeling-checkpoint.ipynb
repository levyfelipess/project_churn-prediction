# %% [markdown]
# # *Setup*

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import numpy as np
from numpy import format_float_positional as ffp
from scipy import stats
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

from time import perf_counter
from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns

from src.preprocessing import clean_data, get_transformers
from src.modeling import random_search_with_kfoldcv, parallelized_random_search_with_kfoldcv
from src.evaluation import (evaluate, evaluate_all_models_and_get_final_comparison_dict,
                            display_best_hyperparam_combinations, display_final_comparison_with_highlight)
from src.utils import save_models, load_models

sns.set_theme(context='notebook', style='ticks')
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['mathtext.fontset'] = 'cm'

# %%
df = pd.read_csv('../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df = clean_data(df)

df_X = df.drop(columns='Churn')
df_y = df.loc[:, ['Churn']].copy()

df_X_train, df_X_test, df_y_train, df_y_test = train_test_split(df_X, df_y, test_size=0.25, shuffle=True, stratify=df_y, random_state=7)
display(df_X_train.shape, df_X_test.shape, df_y_train.shape, df_y_test.shape)

transformers_X, transformer_y = get_transformers(df_X=df_X, df_y=df_y)

models = {}
metrics_final_comparison = {}
model_names_list = ['LR', 'DT', 'RF', 'KNN', 'SVM']
# Out:
# (5282, 19)
# (1761, 19)
# (5282, 1)
# (1761, 1)

# %% [markdown]
# # Treinamento e Avaliação Individual dos Modelos

# %% [markdown]
# ## ***Baseline***: Regressão Logística (**LR**)

# %%
X_train_transformed = transformers_X['LR'].fit_transform(df_X_train)
X_test_transformed = transformers_X['LR'].transform(df_X_test)
y_train = transformer_y.fit_transform(df_y_train)
y_test  = transformer_y.transform(df_y_test)

# %%
models['LR'] = LogisticRegression(C=np.inf,
                                  tol=1e-4,
                                  fit_intercept=True,
                                  solver='lbfgs',
                                  max_iter=1000,
                                  n_jobs=1,
                                  random_state=7)

models['LR'].fit(X=X_train_transformed,
                 y=y_train.reshape(-1))
# Out:
# LogisticRegression(C=inf, max_iter=1000, n_jobs=1, random_state=7)

# %%
metrics_final_comparison['LR'] = evaluate(
    model=models['LR'],
    X_train=X_train_transformed, X_test=X_test_transformed, y_train=y_train, y_test=y_test,
    beta_fscore=2., threshold=1 / (1 + 1), threshold_step=0.001,
    display_metrics_table=True, plot_confusion_matrix=True, plot_roc_prc=True,
    save_metrics_table=True, save_confusion_matrix=True, save_roc_prc=True,
    path_metrics_table='../reports/tables/model-evaluation_LR.csv',
    path_confusion_matrix='../reports/figures/confusion-matrix_LR.png',
    path_roc_prc='../reports/figures/roc-pr-curves_LR.png',
    model_title=' - LR')['Teste']
# Out:
# <style type="text/css">
# </style>
# <table id="T_bbb9d">
#   <caption>Métricas de Avaliação - LR</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbb9d_level0_col0" class="col_heading level0 col0" >Treinamento</th>
#       <th id="T_bbb9d_level0_col1" class="col_heading level0 col1" >Teste</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbb9d_level0_row0" class="row_heading level0 row0" >Acurácia</th>
#       <td id="T_bbb9d_row0_col0" class="data row0 col0" >0.808</td>
#       <td id="T_bbb9d_row0_col1" class="data row0 col1" >0.810</td>
#     </tr>
#     <tr>
#       <th id="T_bbb9d_level0_row1" class="row_heading level0 row1" >Precisão</th>
#       <td id="T_bbb9d_row1_col0" class="data row1 col0" >0.667</td>
#       <td id="T_bbb9d_row1_col1" class="data row1 col1" >0.672</td>
#     </tr>
#     <tr>
#       <th id="T_bbb9d_level0_row2" class="row_heading level0 row2" >Recall</th>
#       <td id="T_bbb9d_row2_col0" class="data row2 col0" >0.553</td>
#       <td id="T_bbb9d_row2_col1" class="data row2 col1" >0.552</td>
#     </tr>
#     <tr>
#       <th id="T_bbb9d_level0_row3" class="row_heading level0 row3" >F1-Score</th>
#       <td id="T_bbb9d_row3_col0" class="data row3 col0" >0.605</td>
#       <td id="T_bbb9d_row3_col1" class="data row3 col1" >0.606</td>
#     </tr>
#     <tr>
#       <th id="T_bbb9d_level0_row4" class="row_heading level0 row4" >F$_{\beta}$-Score</th>
#       <td id="T_bbb9d_row4_col0" class="data row4 col0" >0.572</td>
#       <td id="T_bbb9d_row4_col1" class="data row4 col1" >0.573</td>
#     </tr>
#     <tr>
#       <th id="T_bbb9d_level0_row5" class="row_heading level0 row5" >AUROC</th>
#       <td id="T_bbb9d_row5_col0" class="data row5 col0" >-----</td>
#       <td id="T_bbb9d_row5_col1" class="data row5 col1" >0.858</td>
#     </tr>
#     <tr>
#       <th id="T_bbb9d_level0_row6" class="row_heading level0 row6" >AUPRC</th>
#       <td id="T_bbb9d_row6_col0" class="data row6 col0" >-----</td>
#       <td id="T_bbb9d_row6_col1" class="data row6 col1" >0.679</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Árvore de Decisão (**DT**)

# %% [markdown]
# ### Otimização de Hiperparâmetros

# %%
hyperparam_dist = {'ccp_alpha':stats.loguniform(a=1e-4, b=1e3),
                   'criterion':['gini', 'entropy'],
                   'min_samples_split':stats.randint(2, 40+1)}

df_hyperparam_optimization = parallelized_random_search_with_kfoldcv(model=DecisionTreeClassifier(random_state=7),
                                                                     n_comb=1000, k=5,
                                                                     transformer_X=transformers_X['DT'], transformer_y=transformer_y,
                                                                     df_X_train=df_X_train, df_y_train=df_y_train,
                                                                     hyperparam_distributions=hyperparam_dist,
                                                                     n_jobs=5,
                                                                     global_seed=7)
#df_hyperparam_optimization.to_csv('../reports/tables/hyperparam-optimization_DT.csv')

display_best_hyperparam_combinations(df=df_hyperparam_optimization,
                                     with_one_standard_error_rule=True,
                                     metric_mean_column='auc (mean)',
                                     metric_se_column='auc (se)',
                                     style_format={'ccp_alpha':lambda x: ffp(x)})
# Out:
# <style type="text/css">
# </style>
# <table id="T_60f42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60f42_level0_col0" class="col_heading level0 col0" >ccp_alpha</th>
#       <th id="T_60f42_level0_col1" class="col_heading level0 col1" >criterion</th>
#       <th id="T_60f42_level0_col2" class="col_heading level0 col2" >min_samples_split</th>
#       <th id="T_60f42_level0_col3" class="col_heading level0 col3" >auc (mean)</th>
#       <th id="T_60f42_level0_col4" class="col_heading level0 col4" >auc (std)</th>
#       <th id="T_60f42_level0_col5" class="col_heading level0 col5" >auc (se)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60f42_level0_row0" class="row_heading level0 row0" >950</th>
#       <td id="T_60f42_row0_col0" class="data row0 col0" >0.0025588536991464654</td>
#       <td id="T_60f42_row0_col1" class="data row0 col1" >entropy</td>
#       <td id="T_60f42_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_60f42_row0_col3" class="data row0 col3" >0.825327</td>
#       <td id="T_60f42_row0_col4" class="data row0 col4" >0.009445</td>
#       <td id="T_60f42_row0_col5" class="data row0 col5" >0.004224</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row1" class="row_heading level0 row1" >734</th>
#       <td id="T_60f42_row1_col0" class="data row1 col0" >0.0025780863732141517</td>
#       <td id="T_60f42_row1_col1" class="data row1 col1" >entropy</td>
#       <td id="T_60f42_row1_col2" class="data row1 col2" >11</td>
#       <td id="T_60f42_row1_col3" class="data row1 col3" >0.825327</td>
#       <td id="T_60f42_row1_col4" class="data row1 col4" >0.009445</td>
#       <td id="T_60f42_row1_col5" class="data row1 col5" >0.004224</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_60f42_row2_col0" class="data row2 col0" >0.002716086719845421</td>
#       <td id="T_60f42_row2_col1" class="data row2 col1" >entropy</td>
#       <td id="T_60f42_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_60f42_row2_col3" class="data row2 col3" >0.825207</td>
#       <td id="T_60f42_row2_col4" class="data row2 col4" >0.009578</td>
#       <td id="T_60f42_row2_col5" class="data row2 col5" >0.004283</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row3" class="row_heading level0 row3" >453</th>
#       <td id="T_60f42_row3_col0" class="data row3 col0" >0.0026797550974218065</td>
#       <td id="T_60f42_row3_col1" class="data row3 col1" >entropy</td>
#       <td id="T_60f42_row3_col2" class="data row3 col2" >29</td>
#       <td id="T_60f42_row3_col3" class="data row3 col3" >0.825207</td>
#       <td id="T_60f42_row3_col4" class="data row3 col4" >0.009578</td>
#       <td id="T_60f42_row3_col5" class="data row3 col5" >0.004283</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row4" class="row_heading level0 row4" >655</th>
#       <td id="T_60f42_row4_col0" class="data row4 col0" >0.0018799250614313662</td>
#       <td id="T_60f42_row4_col1" class="data row4 col1" >entropy</td>
#       <td id="T_60f42_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_60f42_row4_col3" class="data row4 col3" >0.824398</td>
#       <td id="T_60f42_row4_col4" class="data row4 col4" >0.006088</td>
#       <td id="T_60f42_row4_col5" class="data row4 col5" >0.002722</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row5" class="row_heading level0 row5" >778</th>
#       <td id="T_60f42_row5_col0" class="data row5 col0" >0.0020716321265925354</td>
#       <td id="T_60f42_row5_col1" class="data row5 col1" >entropy</td>
#       <td id="T_60f42_row5_col2" class="data row5 col2" >31</td>
#       <td id="T_60f42_row5_col3" class="data row5 col3" >0.824378</td>
#       <td id="T_60f42_row5_col4" class="data row5 col4" >0.008559</td>
#       <td id="T_60f42_row5_col5" class="data row5 col5" >0.003828</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row6" class="row_heading level0 row6" >219</th>
#       <td id="T_60f42_row6_col0" class="data row6 col0" >0.002071140208814707</td>
#       <td id="T_60f42_row6_col1" class="data row6 col1" >entropy</td>
#       <td id="T_60f42_row6_col2" class="data row6 col2" >32</td>
#       <td id="T_60f42_row6_col3" class="data row6 col3" >0.824378</td>
#       <td id="T_60f42_row6_col4" class="data row6 col4" >0.008559</td>
#       <td id="T_60f42_row6_col5" class="data row6 col5" >0.003828</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row7" class="row_heading level0 row7" >187</th>
#       <td id="T_60f42_row7_col0" class="data row7 col0" >0.0027797196395198728</td>
#       <td id="T_60f42_row7_col1" class="data row7 col1" >entropy</td>
#       <td id="T_60f42_row7_col2" class="data row7 col2" >18</td>
#       <td id="T_60f42_row7_col3" class="data row7 col3" >0.824240</td>
#       <td id="T_60f42_row7_col4" class="data row7 col4" >0.008740</td>
#       <td id="T_60f42_row7_col5" class="data row7 col5" >0.003908</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row8" class="row_heading level0 row8" >184</th>
#       <td id="T_60f42_row8_col0" class="data row8 col0" >0.0022261659343238895</td>
#       <td id="T_60f42_row8_col1" class="data row8 col1" >entropy</td>
#       <td id="T_60f42_row8_col2" class="data row8 col2" >36</td>
#       <td id="T_60f42_row8_col3" class="data row8 col3" >0.824147</td>
#       <td id="T_60f42_row8_col4" class="data row8 col4" >0.010528</td>
#       <td id="T_60f42_row8_col5" class="data row8 col5" >0.004708</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row9" class="row_heading level0 row9" >415</th>
#       <td id="T_60f42_row9_col0" class="data row9 col0" >0.002220981905763782</td>
#       <td id="T_60f42_row9_col1" class="data row9 col1" >entropy</td>
#       <td id="T_60f42_row9_col2" class="data row9 col2" >36</td>
#       <td id="T_60f42_row9_col3" class="data row9 col3" >0.824147</td>
#       <td id="T_60f42_row9_col4" class="data row9 col4" >0.010528</td>
#       <td id="T_60f42_row9_col5" class="data row9 col5" >0.004708</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row10" class="row_heading level0 row10" >447</th>
#       <td id="T_60f42_row10_col0" class="data row10 col0" >0.0028075893645747984</td>
#       <td id="T_60f42_row10_col1" class="data row10 col1" >entropy</td>
#       <td id="T_60f42_row10_col2" class="data row10 col2" >38</td>
#       <td id="T_60f42_row10_col3" class="data row10 col3" >0.824055</td>
#       <td id="T_60f42_row10_col4" class="data row10 col4" >0.008793</td>
#       <td id="T_60f42_row10_col5" class="data row10 col5" >0.003932</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row11" class="row_heading level0 row11" >569</th>
#       <td id="T_60f42_row11_col0" class="data row11 col0" >0.002874907516037015</td>
#       <td id="T_60f42_row11_col1" class="data row11 col1" >entropy</td>
#       <td id="T_60f42_row11_col2" class="data row11 col2" >4</td>
#       <td id="T_60f42_row11_col3" class="data row11 col3" >0.824055</td>
#       <td id="T_60f42_row11_col4" class="data row11 col4" >0.008793</td>
#       <td id="T_60f42_row11_col5" class="data row11 col5" >0.003932</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row12" class="row_heading level0 row12" >908</th>
#       <td id="T_60f42_row12_col0" class="data row12 col0" >0.0020280358191880976</td>
#       <td id="T_60f42_row12_col1" class="data row12 col1" >entropy</td>
#       <td id="T_60f42_row12_col2" class="data row12 col2" >31</td>
#       <td id="T_60f42_row12_col3" class="data row12 col3" >0.823948</td>
#       <td id="T_60f42_row12_col4" class="data row12 col4" >0.007217</td>
#       <td id="T_60f42_row12_col5" class="data row12 col5" >0.003227</td>
#     </tr>
#     <tr>
#       <th id="T_60f42_level0_row13" class="row_heading level0 row13" >592</th>
#       <td id="T_60f42_row13_col0" class="data row13 col0" >0.0022897133444280686</td>
#       <td id="T_60f42_row13_col1" class="data row13 col1" >entropy</td>
#       <td id="T_60f42_row13_col2" class="data row13 col2" >15</td>
#       <td id="T_60f42_row13_col3" class="data row13 col3" >0.823860</td>
#       <td id="T_60f42_row13_col4" class="data row13 col4" >0.0

# %% [markdown]
# ### Treinamento final e Avaliação

# %%
X_train_transformed = transformers_X['DT'].fit_transform(df_X_train)
X_test_transformed = transformers_X['DT'].transform(df_X_test)
y_train = transformer_y.fit_transform(df_y_train)
y_test  = transformer_y.transform(df_y_test)

# %%
# Combinação de hiperparâmetros nº 447
models['DT'] = DecisionTreeClassifier(ccp_alpha=0.0028075893645747984,
                                      min_samples_split=38,
                                      criterion='entropy',
                                      random_state=7)
models['DT'].fit(X=X_train_transformed,
                 y=y_train.reshape(-1))
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0028075893645747984, criterion='entropy',
#                        min_samples_split=38, random_state=7)

# %%
metrics_final_comparison['DT'] = evaluate(
    model=models['DT'],
    X_train=X_train_transformed, X_test=X_test_transformed, y_train=y_train, y_test=y_test,
    beta_fscore=2., threshold=1 / (1 + 1), threshold_step=0.001,
    display_metrics_table=True, plot_confusion_matrix=True, plot_roc_prc=True,
    save_metrics_table=True, save_confusion_matrix=True, save_roc_prc=True,
    path_metrics_table='../reports/tables/model-evaluation_DT.csv',
    path_confusion_matrix='../reports/figures/confusion-matrix_DT.png',
    path_roc_prc='../reports/figures/roc-pr-curves_DT.png',
    model_title=' - DT')['Teste']
# Out:
# <style type="text/css">
# </style>
# <table id="T_ec5ee">
#   <caption>Métricas de Avaliação - DT</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec5ee_level0_col0" class="col_heading level0 col0" >Treinamento</th>
#       <th id="T_ec5ee_level0_col1" class="col_heading level0 col1" >Teste</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec5ee_level0_row0" class="row_heading level0 row0" >Acurácia</th>
#       <td id="T_ec5ee_row0_col0" class="data row0 col0" >0.791</td>
#       <td id="T_ec5ee_row0_col1" class="data row0 col1" >0.793</td>
#     </tr>
#     <tr>
#       <th id="T_ec5ee_level0_row1" class="row_heading level0 row1" >Precisão</th>
#       <td id="T_ec5ee_row1_col0" class="data row1 col0" >0.684</td>
#       <td id="T_ec5ee_row1_col1" class="data row1 col1" >0.677</td>
#     </tr>
#     <tr>
#       <th id="T_ec5ee_level0_row2" class="row_heading level0 row2" >Recall</th>
#       <td id="T_ec5ee_row2_col0" class="data row2 col0" >0.392</td>
#       <td id="T_ec5ee_row2_col1" class="data row2 col1" >0.418</td>
#     </tr>
#     <tr>
#       <th id="T_ec5ee_level0_row3" class="row_heading level0 row3" >F1-Score</th>
#       <td id="T_ec5ee_row3_col0" class="data row3 col0" >0.499</td>
#       <td id="T_ec5ee_row3_col1" class="data row3 col1" >0.517</td>
#     </tr>
#     <tr>
#       <th id="T_ec5ee_level0_row4" class="row_heading level0 row4" >F$_{\beta}$-Score</th>
#       <td id="T_ec5ee_row4_col0" class="data row4 col0" >0.429</td>
#       <td id="T_ec5ee_row4_col1" class="data row4 col1" >0.452</td>
#     </tr>
#     <tr>
#       <th id="T_ec5ee_level0_row5" class="row_heading level0 row5" >AUROC</th>
#       <td id="T_ec5ee_row5_col0" class="data row5 col0" >-----</td>
#       <td id="T_ec5ee_row5_col1" class="data row5 col1" >0.837</td>
#     </tr>
#     <tr>
#       <th id="T_ec5ee_level0_row6" class="row_heading level0 row6" >AUPRC</th>
#       <td id="T_ec5ee_row6_col0" class="data row6 col0" >-----</td>
#       <td id="T_ec5ee_row6_col1" class="data row6 col1" >0.665</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Floresta Aleatória (**RF**)

# %% [markdown]
# ### Otimização de Hiperparâmetros

# %%
hyperparam_dist = {'n_estimators':stats.randint(10, 500+1),
                   'criterion':['gini', 'entropy'],
                   'max_features':stats.uniform(0, 1),
                   'max_depth':list(range(2, 20+1, 2)) + [None]}

df_hyperparam_optimization = random_search_with_kfoldcv(model=RandomForestClassifier(random_state=7, n_jobs=-1),
                                                        n_comb=100, k=5,
                                                        transformer_X=transformers_X['RF'], transformer_y=transformer_y,
                                                        df_X_train=df_X_train, df_y_train=df_y_train,
                                                        hyperparam_distributions=hyperparam_dist,
                                                        verbose_tqdm=True,
                                                        global_seed=7)
#df_hyperparam_optimization.to_csv('../reports/tables/hyperparam-optimization_RF.csv')

display_best_hyperparam_combinations(df=df_hyperparam_optimization,
                                     with_one_standard_error_rule=True,
                                     metric_mean_column='auc (mean)',
                                     metric_se_column='auc (se)',
                                     style_format={'max_features':lambda x: ffp(x)})
# Out:
# Validação Cruzada K-Fold - 1/5: 100%|████████████████████████████████████████████████| 100/100 [02:01<00:00,  1.22s/it]
# Validação Cruzada K-Fold - 2/5: 100%|████████████████████████████████████████████████| 100/100 [04:38<00:00,  2.78s/it]
# Validação Cruzada K-Fold - 3/5: 100%|████████████████████████████████████████████████| 100/100 [09:15<00:00,  5.56s/it]
# Validação Cruzada K-Fold - 4/5: 100%|████████████████████████████████████████████████| 100/100 [17:26<00:00, 10.47s/it]
# Validação Cruzada K-Fold - 5/5: 100%|████████████████████████████████████████████████| 100/100 [32:38<00:00, 19.59s/it]
# <style type="text/css">
# </style>
# <table id="T_9d31e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d31e_level0_col0" class="col_heading level0 col0" >n_estimators</th>
#       <th id="T_9d31e_level0_col1" class="col_heading level0 col1" >criterion</th>
#       <th id="T_9d31e_level0_col2" class="col_heading level0 col2" >max_features</th>
#       <th id="T_9d31e_level0_col3" class="col_heading level0 col3" >max_depth</th>
#       <th id="T_9d31e_level0_col4" class="col_heading level0 col4" >auc (mean)</th>
#       <th id="T_9d31e_level0_col5" class="col_heading level0 col5" >auc (std)</th>
#       <th id="T_9d31e_level0_col6" class="col_heading level0 col6" >auc (se)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d31e_level0_row0" class="row_heading level0 row0" >81</th>
#       <td id="T_9d31e_row0_col0" class="data row0 col0" >389</td>
#       <td id="T_9d31e_row0_col1" class="data row0 col1" >gini</td>
#       <td id="T_9d31e_row0_col2" class="data row0 col2" >0.414901772573252</td>
#       <td id="T_9d31e_row0_col3" class="data row0 col3" >6</td>
#       <td id="T_9d31e_row0_col4" class="data row0 col4" >0.841928</td>
#       <td id="T_9d31e_row0_col5" class="data row0 col5" >0.012438</td>
#       <td id="T_9d31e_row0_col6" class="data row0 col6" >0.005562</td>
#     </tr>
#     <tr>
#       <th id="T_9d31e_level0_row1" class="row_heading level0 row1" >41</th>
#       <td id="T_9d31e_row1_col0" class="data row1 col0" >458</td>
#       <td id="T_9d31e_row1_col1" class="data row1 col1" >gini</td>
#       <td id="T_9d31e_row1_col2" class="data row1 col2" >0.3529783659443947</td>
#       <td id="T_9d31e_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_9d31e_row1_col4" class="data row1 col4" >0.841890</td>
#       <td id="T_9d31e_row1_col5" class="data row1 col5" >0.012517</td>
#       <td id="T_9d31e_row1_col6" class="data row1 col6" >0.005598</td>
#     </tr>
#     <tr>
#       <th id="T_9d31e_level0_row2" class="row_heading level0 row2" >63</th>
#       <td id="T_9d31e_row2_col0" class="data row2 col0" >262</td>
#       <td id="T_9d31e_row2_col1" class="data row2 col1" >gini</td>
#       <td id="T_9d31e_row2_col2" class="data row2 col2" >0.30885268486379713</td>
#       <td id="T_9d31e_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_9d31e_row2_col4" class="data row2 col4" >0.841652</td>
#       <td id="T_9d31e_row2_col5" class="data row2 col5" >0.012437</td>
#       <td id="T_9d31e_row2_col6" class="data row2 col6" >0.005562</td>
#     </tr>
#     <tr>
#       <th id="T_9d31e_level0_row3" class="row_heading level0 row3" >94</th>
#       <td id="T_9d31e_row3_col0" class="data row3 col0" >487</td>
#       <td id="T_9d31e_row3_col1" class="data row3 col1" >gini</td>
#       <td id="T_9d31e_row3_col2" class="data row3 col2" >0.2765630724511342</td>
#       <td id="T_9d31e_row3_col3" class="data row3 col3" >6</td>
#       <td id="T_9d31e_row3_col4" class="data row3 col4" >0.841414</td>
#       <td id="T_9d31e_row3_col5" class="data row3 col5" >0.012530</td>
#       <td id="T_9d31e_row3_col6" class="data row3 col6" >0.005604</td>
#     </tr>
#     <tr>
#       <th id="T_9d31e_level0_row4" class="row_heading level0 row4" >71</th>
#       <td id="T_9d31e_row4_col0" class="data row4 col0" >401</td>
#       <td id="T_9d31e_row4_col1" class="data row4 col1" >gini</td>
#       <td id="T_9d31e_row4_col2" class="data row4 col2" >0.13111064234791392</td>
#       <td id="T_9d31e_row4_col3" class="data row4 col3" >6</td>
#       <td id="T_9d31e_row4_col4" class="data row4 col4" >0.840309</td>
#       <td id="T_9d31e_row4_col5" class="data row4 col5" >0.014485</td>
#       <td id="T_9d31e_row4_col6" class="data row4 col6" >0.006478</td>
#     </tr>
#     <tr>
#       <th id="T_9d31e_level0_row5" class="row_heading level0 row5" >60</th>
#       <td id="T_9d31e_row5_col0" class="data row5 col0" >359</td>
#       <td id="T_9d31e_row5_col1" class="data row5 col1" >gini</td>
#       <td id="T_9d31e_row5_col2" class="data row5 col2" >0.955468323002926</td>
#       <td id="T_9d31e_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_9d31e_row5_col4" class="data row5 col4" >0.839985</td>
#       <td id="T_9d31e_row5_col5" class="data row5 col5" >0.012002</td>
#       <td id="T_9d31e_row5_col6" class="data row5 col6" >0.005367</td>
#     </tr>
#     <tr>
#       <th id="T_9d31e_level0_row6" class="row_heading level0 row6" >25</th>
#       <td id="T_9d31e_row6_col0" class="data row6 col0" >85</td>
#       <td id="T_9d31e_row6_col1" class="data row6 col1" >gini</td>
#       <td id="T_9d31e_row6_col2" class="data row6 col2" >0.13316944575925016</td>
#       <td id="T_9d31e_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_9d31e_row6_col4" class="data row6 col4" >0.839800</td>
#       <td id="T_9d31e_row6_col5" class="data row6 col5" >0.015130</td>
#       <td id="T_9d31e_row6_col6" class="data row6 col6" >0.006766</td>
#     </tr>
#     <tr>
#       <th id="T_9d31e_level0_row7" class="row_heading level0 row7" >22</th>
#       <td id="T_9d31e_row7_col0" class="data row7 col0" >401</td>
#       <td id="T_9d31e_row7_col1" class="data row7 col1" >gini</td>
#       <td id="T_9d31e_row7_col2" class="data row7 col2" >0.2303028790209648</td>
#       <td id="T_9d31e_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_9d31e_row7_col4" class="data row7 col4" >0.839634</td>
#       <td id="T_9d31e_row7_col5" class="data row7 col5" >0.013169</td>
#       <td id="T_9d31e_row7_col6" class="data row7 col6" >0.005889</td>
#     </tr>
#     <tr>
#       <th id="T_9d31e_level0_row8" class="row_heading level0 row8" >67</th>
#       <td id="T_9d31e_row8_col0" class="data row8 col0" >243</td>
#       <td id="T_9d31e_row8_col1" class="data row8 col1" >gini</td>
#       <td id="T_9d31e_row8_col2" class="data row8 col2" >0.9450482237927939</td>
#       <td id="T_9d31e_row8_col3" class="data row8 col3" >6</td>
#       <td id="T_9d31e_row8_col4" class="data row8 col4" >0.839627</td>
#       <td id="T_9d31e_row8_col5" class="data row8 col5" >0.011862</td>
#       <td id="T_9d31e_row8_col6" class="data row8 col6" >0.005305</td>
#     </tr>
#     <tr>
#       <th id="T_9d31e_level0_row9" class="row_heading level0 row9" >43</th>
#       <td id="T_9d31e_row9_col0" class="data row9 col0" >322</td>
#       <td id="T_9d31e_row9_col1" class="data row9 col1" >gini</td>
#       <td id="T_9d31e_row9_col2" class="data row9 col2" >0.3703510829880352</td>
#       <td id="T_9d31e_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_9d31e_row9_col4" class="data row9 col4" >0.838682</td>
#       <td id="T_9d31e_row9_col5" class="data row9 col5" >0.013343</td>
#       <td id="T_9d31e_row9_col6" class="data row9 col6" >0.005967</td>
#     </tr>
#     <tr>
#       <th id="T_9d31e_level0_row10" class="row_heading level0 row10" >79</th>
#       <td id="T_9d31e_row10_col0" class="data row10 col0" >491</td>
#       <td id="T_9d31e_row10_col1" class="data row10 col1" >gini</td>
#       <td id="T_9d31e_row10_col2" class="data row10 col2" >0.30041890431803975</td>
#       <td id="T_9d31e_row10_col3" class="data row10 col3" >4</td>
#       <td id="T_9d31e_row10_col4" class="data row10 col4" >0.838605</td>
#       <td id="T_9d31e_row10_col5" class="data row10 col5" >0.014160</td>
#       <td id="T_9d31e_row10_col6" class="data row10 col6" >0.006333</td>
#     </tr>
#     <tr>
#       <th id="T_9d31e_level0_row11" class="row_heading level0 row11" >50</th>
#       <td id="T_9d31e_row11_col0" class="data row11 col0" >493</td>
#       <td id="T_9d31e_row11_col1" class="data row11 col1" >gini</td>
#       <td id="T_9d31e_row11_col2" class="data row11 col2" >0.42237404364314035</td>
#       <td id="T_9d31e_row11_col3" class="data row11 col3" >4</td>
#       <td id="T_9d31e_row11_col4" class="data row11 col4" >0.838590</td>
#       <td id="T_9d31e_row11_col5" class="data row11 col5" >0.013168</td>
#       <td id="T_9d31e_row11_col6" class="data row11 col6" >0.005889</td>
#     </tr>
#     <tr>
#       <th id="T_9d31e_level0_row12" class="row_heading level0 row12" >16</th>
#       <td id="T_9d31e_row12_col0" class="data row12 col0" >402</td>
#       <td id="T_9d31e_row12_col1" class="dat

# %% [markdown]
# ### Treinamento final e Avaliação

# %%
X_train_transformed = transformers_X['RF'].fit_transform(df_X_train)
X_test_transformed = transformers_X['RF'].transform(df_X_test)
y_train = transformer_y.fit_transform(df_y_train)
y_test  = transformer_y.transform(df_y_test)

# %%
# Combinação de hiperparâmetros nº 84
models['RF'] = RandomForestClassifier(n_estimators=29,
                                      max_features=0.7963907007825485,
                                      criterion='gini',
                                      max_depth=6,
                                      n_jobs=-1,
                                      random_state=7)
models['RF'].fit(X=X_train_transformed,
                 y=y_train.reshape(-1))
# Out:
# RandomForestClassifier(max_depth=6, max_features=0.7963907007825485,
#                        n_estimators=29, n_jobs=-1, random_state=7)

# %%
metrics_final_comparison['RF'] = evaluate(
    model=models['RF'],
    X_train=X_train_transformed, X_test=X_test_transformed, y_train=y_train, y_test=y_test,
    beta_fscore=2., threshold=1 / (1 + 1), threshold_step=0.001,
    display_metrics_table=True, plot_confusion_matrix=True, plot_roc_prc=True,
    save_metrics_table=True, save_confusion_matrix=True, save_roc_prc=True,
    path_metrics_table='../reports/tables/model-evaluation_RF.csv',
    path_confusion_matrix='../reports/figures/confusion-matrix_RF.png',
    path_roc_prc='../reports/figures/roc-pr-curves_RF.png',
    model_title=' - RF')['Teste']
# Out:
# <style type="text/css">
# </style>
# <table id="T_5dcc3">
#   <caption>Métricas de Avaliação - RF</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5dcc3_level0_col0" class="col_heading level0 col0" >Treinamento</th>
#       <th id="T_5dcc3_level0_col1" class="col_heading level0 col1" >Teste</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dcc3_level0_row0" class="row_heading level0 row0" >Acurácia</th>
#       <td id="T_5dcc3_row0_col0" class="data row0 col0" >0.819</td>
#       <td id="T_5dcc3_row0_col1" class="data row0 col1" >0.809</td>
#     </tr>
#     <tr>
#       <th id="T_5dcc3_level0_row1" class="row_heading level0 row1" >Precisão</th>
#       <td id="T_5dcc3_row1_col0" class="data row1 col0" >0.711</td>
#       <td id="T_5dcc3_row1_col1" class="data row1 col1" >0.686</td>
#     </tr>
#     <tr>
#       <th id="T_5dcc3_level0_row2" class="row_heading level0 row2" >Recall</th>
#       <td id="T_5dcc3_row2_col0" class="data row2 col0" >0.536</td>
#       <td id="T_5dcc3_row2_col1" class="data row2 col1" >0.518</td>
#     </tr>
#     <tr>
#       <th id="T_5dcc3_level0_row3" class="row_heading level0 row3" >F1-Score</th>
#       <td id="T_5dcc3_row3_col0" class="data row3 col0" >0.611</td>
#       <td id="T_5dcc3_row3_col1" class="data row3 col1" >0.590</td>
#     </tr>
#     <tr>
#       <th id="T_5dcc3_level0_row4" class="row_heading level0 row4" >F$_{\beta}$-Score</th>
#       <td id="T_5dcc3_row4_col0" class="data row4 col0" >0.563</td>
#       <td id="T_5dcc3_row4_col1" class="data row4 col1" >0.545</td>
#     </tr>
#     <tr>
#       <th id="T_5dcc3_level0_row5" class="row_heading level0 row5" >AUROC</th>
#       <td id="T_5dcc3_row5_col0" class="data row5 col0" >-----</td>
#       <td id="T_5dcc3_row5_col1" class="data row5 col1" >0.854</td>
#     </tr>
#     <tr>
#       <th id="T_5dcc3_level0_row6" class="row_heading level0 row6" >AUPRC</th>
#       <td id="T_5dcc3_row6_col0" class="data row6 col0" >-----</td>
#       <td id="T_5dcc3_row6_col1" class="data row6 col1" >0.683</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## K-Vizinhos mais Próximos (**KNN**)

# %% [markdown]
# ### Otimização de Hiperparâmetros

# %%
hyperparam_dist = {'n_neighbors':stats.randint(1, 200+1),
                   'weights':['uniform', 'distance'],
                   'p':stats.randint(1, 5+1)}

df_hyperparam_optimization = parallelized_random_search_with_kfoldcv(model=KNeighborsClassifier(metric='minkowski'),
                                                                     n_comb=1000, k=5,
                                                                     transformer_X=transformers_X['KNN'], transformer_y=transformer_y,
                                                                     df_X_train=df_X_train, df_y_train=df_y_train,
                                                                     hyperparam_distributions=hyperparam_dist,
                                                                     n_jobs=5,
                                                                     global_seed=7)
#df_hyperparam_optimization.to_csv('../reports/tables/hyperparam-optimization_KNN.csv')

display_best_hyperparam_combinations(df=df_hyperparam_optimization,
                                     with_one_standard_error_rule=True,
                                     metric_mean_column='auc (mean)',
                                     metric_se_column='auc (se)')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c3cf1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3cf1_level0_col0" class="col_heading level0 col0" >n_neighbors</th>
#       <th id="T_c3cf1_level0_col1" class="col_heading level0 col1" >weights</th>
#       <th id="T_c3cf1_level0_col2" class="col_heading level0 col2" >p</th>
#       <th id="T_c3cf1_level0_col3" class="col_heading level0 col3" >auc (mean)</th>
#       <th id="T_c3cf1_level0_col4" class="col_heading level0 col4" >auc (std)</th>
#       <th id="T_c3cf1_level0_col5" class="col_heading level0 col5" >auc (se)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3cf1_level0_row0" class="row_heading level0 row0" >730</th>
#       <td id="T_c3cf1_row0_col0" class="data row0 col0" >108</td>
#       <td id="T_c3cf1_row0_col1" class="data row0 col1" >uniform</td>
#       <td id="T_c3cf1_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_c3cf1_row0_col3" class="data row0 col3" >0.831602</td>
#       <td id="T_c3cf1_row0_col4" class="data row0 col4" >0.017013</td>
#       <td id="T_c3cf1_row0_col5" class="data row0 col5" >0.007608</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row1" class="row_heading level0 row1" >159</th>
#       <td id="T_c3cf1_row1_col0" class="data row1 col0" >108</td>
#       <td id="T_c3cf1_row1_col1" class="data row1 col1" >uniform</td>
#       <td id="T_c3cf1_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_c3cf1_row1_col3" class="data row1 col3" >0.831602</td>
#       <td id="T_c3cf1_row1_col4" class="data row1 col4" >0.017013</td>
#       <td id="T_c3cf1_row1_col5" class="data row1 col5" >0.007608</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row2" class="row_heading level0 row2" >608</th>
#       <td id="T_c3cf1_row2_col0" class="data row2 col0" >107</td>
#       <td id="T_c3cf1_row2_col1" class="data row2 col1" >uniform</td>
#       <td id="T_c3cf1_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_c3cf1_row2_col3" class="data row2 col3" >0.831543</td>
#       <td id="T_c3cf1_row2_col4" class="data row2 col4" >0.017102</td>
#       <td id="T_c3cf1_row2_col5" class="data row2 col5" >0.007648</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row3" class="row_heading level0 row3" >970</th>
#       <td id="T_c3cf1_row3_col0" class="data row3 col0" >107</td>
#       <td id="T_c3cf1_row3_col1" class="data row3 col1" >uniform</td>
#       <td id="T_c3cf1_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_c3cf1_row3_col3" class="data row3 col3" >0.831543</td>
#       <td id="T_c3cf1_row3_col4" class="data row3 col4" >0.017102</td>
#       <td id="T_c3cf1_row3_col5" class="data row3 col5" >0.007648</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row4" class="row_heading level0 row4" >146</th>
#       <td id="T_c3cf1_row4_col0" class="data row4 col0" >106</td>
#       <td id="T_c3cf1_row4_col1" class="data row4 col1" >uniform</td>
#       <td id="T_c3cf1_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_c3cf1_row4_col3" class="data row4 col3" >0.831473</td>
#       <td id="T_c3cf1_row4_col4" class="data row4 col4" >0.016928</td>
#       <td id="T_c3cf1_row4_col5" class="data row4 col5" >0.007571</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row5" class="row_heading level0 row5" >372</th>
#       <td id="T_c3cf1_row5_col0" class="data row5 col0" >104</td>
#       <td id="T_c3cf1_row5_col1" class="data row5 col1" >uniform</td>
#       <td id="T_c3cf1_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_c3cf1_row5_col3" class="data row5 col3" >0.831451</td>
#       <td id="T_c3cf1_row5_col4" class="data row5 col4" >0.017021</td>
#       <td id="T_c3cf1_row5_col5" class="data row5 col5" >0.007612</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row6" class="row_heading level0 row6" >613</th>
#       <td id="T_c3cf1_row6_col0" class="data row6 col0" >103</td>
#       <td id="T_c3cf1_row6_col1" class="data row6 col1" >uniform</td>
#       <td id="T_c3cf1_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_c3cf1_row6_col3" class="data row6 col3" >0.831414</td>
#       <td id="T_c3cf1_row6_col4" class="data row6 col4" >0.017057</td>
#       <td id="T_c3cf1_row6_col5" class="data row6 col5" >0.007628</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row7" class="row_heading level0 row7" >410</th>
#       <td id="T_c3cf1_row7_col0" class="data row7 col0" >103</td>
#       <td id="T_c3cf1_row7_col1" class="data row7 col1" >uniform</td>
#       <td id="T_c3cf1_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_c3cf1_row7_col3" class="data row7 col3" >0.831414</td>
#       <td id="T_c3cf1_row7_col4" class="data row7 col4" >0.017057</td>
#       <td id="T_c3cf1_row7_col5" class="data row7 col5" >0.007628</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row8" class="row_heading level0 row8" >166</th>
#       <td id="T_c3cf1_row8_col0" class="data row8 col0" >110</td>
#       <td id="T_c3cf1_row8_col1" class="data row8 col1" >uniform</td>
#       <td id="T_c3cf1_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_c3cf1_row8_col3" class="data row8 col3" >0.831414</td>
#       <td id="T_c3cf1_row8_col4" class="data row8 col4" >0.017155</td>
#       <td id="T_c3cf1_row8_col5" class="data row8 col5" >0.007672</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row9" class="row_heading level0 row9" >634</th>
#       <td id="T_c3cf1_row9_col0" class="data row9 col0" >109</td>
#       <td id="T_c3cf1_row9_col1" class="data row9 col1" >uniform</td>
#       <td id="T_c3cf1_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_c3cf1_row9_col3" class="data row9 col3" >0.831366</td>
#       <td id="T_c3cf1_row9_col4" class="data row9 col4" >0.017199</td>
#       <td id="T_c3cf1_row9_col5" class="data row9 col5" >0.007692</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row10" class="row_heading level0 row10" >756</th>
#       <td id="T_c3cf1_row10_col0" class="data row10 col0" >72</td>
#       <td id="T_c3cf1_row10_col1" class="data row10 col1" >uniform</td>
#       <td id="T_c3cf1_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_c3cf1_row10_col3" class="data row10 col3" >0.831363</td>
#       <td id="T_c3cf1_row10_col4" class="data row10 col4" >0.015898</td>
#       <td id="T_c3cf1_row10_col5" class="data row10 col5" >0.007110</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row11" class="row_heading level0 row11" >374</th>
#       <td id="T_c3cf1_row11_col0" class="data row11 col0" >73</td>
#       <td id="T_c3cf1_row11_col1" class="data row11 col1" >uniform</td>
#       <td id="T_c3cf1_row11_col2" class="data row11 col2" >1</td>
#       <td id="T_c3cf1_row11_col3" class="data row11 col3" >0.831298</td>
#       <td id="T_c3cf1_row11_col4" class="data row11 col4" >0.015903</td>
#       <td id="T_c3cf1_row11_col5" class="data row11 col5" >0.007112</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row12" class="row_heading level0 row12" >10</th>
#       <td id="T_c3cf1_row12_col0" class="data row12 col0" >73</td>
#       <td id="T_c3cf1_row12_col1" class="data row12 col1" >uniform</td>
#       <td id="T_c3cf1_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_c3cf1_row12_col3" class="data row12 col3" >0.831298</td>
#       <td id="T_c3cf1_row12_col4" class="data row12 col4" >0.015903</td>
#       <td id="T_c3cf1_row12_col5" class="data row12 col5" >0.007112</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row13" class="row_heading level0 row13" >914</th>
#       <td id="T_c3cf1_row13_col0" class="data row13 col0" >102</td>
#       <td id="T_c3cf1_row13_col1" class="data row13 col1" >uniform</td>
#       <td id="T_c3cf1_row13_col2" class="data row13 col2" >1</td>
#       <td id="T_c3cf1_row13_col3" class="data row13 col3" >0.831294</td>
#       <td id="T_c3cf1_row13_col4" class="data row13 col4" >0.017214</td>
#       <td id="T_c3cf1_row13_col5" class="data row13 col5" >0.007698</td>
#     </tr>
#     <tr>
#       <th id="T_c3cf1_level0_row14" class="row_heading level0 row14" >268</th>
#       <td id="T_c3cf1_row14_col0" class="data row14 col0" >92</td>
#       <td id="T_c3cf1_row14_c

# %% [markdown]
# ### Treinamento final e Avaliação

# %%
X_train_transformed = transformers_X['KNN'].fit_transform(df_X_train)
X_test_transformed = transformers_X['KNN'].transform(df_X_test)
y_train = transformer_y.fit_transform(df_y_train)
y_test  = transformer_y.transform(df_y_test)

# %%
models['KNN'] = KNeighborsClassifier(n_neighbors=22,
                                     weights='uniform',
                                     p=2,
                                     metric='minkowski',
                                     n_jobs=-1)
models['KNN'].fit(X=X_train_transformed,
                  y=y_train.reshape(-1))
# Out:
# KNeighborsClassifier(n_jobs=-1, n_neighbors=22)

# %%
metrics_final_comparison['KNN'] = evaluate(
    model=models['KNN'],
    X_train=X_train_transformed, X_test=X_test_transformed, y_train=y_train, y_test=y_test,
    beta_fscore=2., threshold=1 / (1 + 1), threshold_step=0.001,
    display_metrics_table=True, plot_confusion_matrix=True, plot_roc_prc=True,
    save_metrics_table=True, save_confusion_matrix=True, save_roc_prc=True,
    path_metrics_table='../reports/tables/model-evaluation_KNN.csv',
    path_confusion_matrix='../reports/figures/confusion-matrix_KNN.png',
    path_roc_prc='../reports/figures/roc-pr-curves_KNN.png',
    model_title=' - KNN')['Teste']
# Out:
# <style type="text/css">
# </style>
# <table id="T_f28b9">
#   <caption>Métricas de Avaliação - KNN</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f28b9_level0_col0" class="col_heading level0 col0" >Treinamento</th>
#       <th id="T_f28b9_level0_col1" class="col_heading level0 col1" >Teste</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f28b9_level0_row0" class="row_heading level0 row0" >Acurácia</th>
#       <td id="T_f28b9_row0_col0" class="data row0 col0" >0.808</td>
#       <td id="T_f28b9_row0_col1" class="data row0 col1" >0.794</td>
#     </tr>
#     <tr>
#       <th id="T_f28b9_level0_row1" class="row_heading level0 row1" >Precisão</th>
#       <td id="T_f28b9_row1_col0" class="data row1 col0" >0.639</td>
#       <td id="T_f28b9_row1_col1" class="data row1 col1" >0.612</td>
#     </tr>
#     <tr>
#       <th id="T_f28b9_level0_row2" class="row_heading level0 row2" >Recall</th>
#       <td id="T_f28b9_row2_col0" class="data row2 col0" >0.631</td>
#       <td id="T_f28b9_row2_col1" class="data row2 col1" >0.612</td>
#     </tr>
#     <tr>
#       <th id="T_f28b9_level0_row3" class="row_heading level0 row3" >F1-Score</th>
#       <td id="T_f28b9_row3_col0" class="data row3 col0" >0.635</td>
#       <td id="T_f28b9_row3_col1" class="data row3 col1" >0.612</td>
#     </tr>
#     <tr>
#       <th id="T_f28b9_level0_row4" class="row_heading level0 row4" >F$_{\beta}$-Score</th>
#       <td id="T_f28b9_row4_col0" class="data row4 col0" >0.633</td>
#       <td id="T_f28b9_row4_col1" class="data row4 col1" >0.612</td>
#     </tr>
#     <tr>
#       <th id="T_f28b9_level0_row5" class="row_heading level0 row5" >AUROC</th>
#       <td id="T_f28b9_row5_col0" class="data row5 col0" >-----</td>
#       <td id="T_f28b9_row5_col1" class="data row5 col1" >0.847</td>
#     </tr>
#     <tr>
#       <th id="T_f28b9_level0_row6" class="row_heading level0 row6" >AUPRC</th>
#       <td id="T_f28b9_row6_col0" class="data row6 col0" >-----</td>
#       <td id="T_f28b9_row6_col1" class="data row6 col1" >0.658</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Máquinas de Vetores de Suporte (**SVM**)

# %% [markdown]
# ### Otimização de Hiperparâmetros

# %%
hyperparam_dist = {'C':stats.loguniform(2**-10, 2**10),
                   'gamma':stats.loguniform(2**-20, 2**5)}

df_hyperparam_optimization = parallelized_random_search_with_kfoldcv(model=SVC(random_state=7, kernel='rbf', probability=True),
                                                                     n_comb=100, k=5,
                                                                     transformer_X=transformers_X['SVM'], transformer_y=transformer_y,
                                                                     df_X_train=df_X_train, df_y_train=df_y_train,
                                                                     hyperparam_distributions=hyperparam_dist,
                                                                     n_jobs=5,
                                                                     global_seed=7)
#df_hyperparam_optimization.to_csv('../reports/tables/hyperparam-optimization_SVM.csv')

display_best_hyperparam_combinations(df=df_hyperparam_optimization,
                                     n_best=5,
                                     with_one_standard_error_rule=False,
                                     style_format={'C':lambda x:ffp(x), 'gamma':lambda x:ffp(x)})
# Out:
# <style type="text/css">
# </style>
# <table id="T_efcb6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efcb6_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_efcb6_level0_col1" class="col_heading level0 col1" >gamma</th>
#       <th id="T_efcb6_level0_col2" class="col_heading level0 col2" >auc (mean)</th>
#       <th id="T_efcb6_level0_col3" class="col_heading level0 col3" >auc (std)</th>
#       <th id="T_efcb6_level0_col4" class="col_heading level0 col4" >auc (se)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efcb6_level0_row0" class="row_heading level0 row0" >92</th>
#       <td id="T_efcb6_row0_col0" class="data row0 col0" >0.0017158226880264926</td>
#       <td id="T_efcb6_row0_col1" class="data row0 col1" >0.00000192914796952792</td>
#       <td id="T_efcb6_row0_col2" class="data row0 col2" >0.831361</td>
#       <td id="T_efcb6_row0_col3" class="data row0 col3" >0.019382</td>
#       <td id="T_efcb6_row0_col4" class="data row0 col4" >0.008668</td>
#     </tr>
#     <tr>
#       <th id="T_efcb6_level0_row1" class="row_heading level0 row1" >56</th>
#       <td id="T_efcb6_row1_col0" class="data row1 col0" >0.003508930082791008</td>
#       <td id="T_efcb6_row1_col1" class="data row1 col1" >0.000004717842365609852</td>
#       <td id="T_efcb6_row1_col2" class="data row1 col2" >0.831327</td>
#       <td id="T_efcb6_row1_col3" class="data row1 col3" >0.019397</td>
#       <td id="T_efcb6_row1_col4" class="data row1 col4" >0.008674</td>
#     </tr>
#     <tr>
#       <th id="T_efcb6_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_efcb6_row2_col0" class="data row2 col0" >0.001379139923285146</td>
#       <td id="T_efcb6_row2_col1" class="data row2 col1" >0.0000014682007641057004</td>
#       <td id="T_efcb6_row2_col2" class="data row2 col2" >0.831320</td>
#       <td id="T_efcb6_row2_col3" class="data row2 col3" >0.019505</td>
#       <td id="T_efcb6_row2_col4" class="data row2 col4" >0.008723</td>
#     </tr>
#     <tr>
#       <th id="T_efcb6_level0_row3" class="row_heading level0 row3" >16</th>
#       <td id="T_efcb6_row3_col0" class="data row3 col0" >0.018810826796744964</td>
#       <td id="T_efcb6_row3_col1" class="data row3 col1" >0.00003848441491494224</td>
#       <td id="T_efcb6_row3_col2" class="data row3 col2" >0.831281</td>
#       <td id="T_efcb6_row3_col3" class="data row3 col3" >0.019720</td>
#       <td id="T_efcb6_row3_col4" class="data row3 col4" >0.008819</td>
#     </tr>
#     <tr>
#       <th id="T_efcb6_level0_row4" class="row_heading level0 row4" >55</th>
#       <td id="T_efcb6_row4_col0" class="data row4 col0" >0.0009960719731237507</td>
#       <td id="T_efcb6_row4_col1" class="data row4 col1" >0.0000009775487685593361</td>
#       <td id="T_efcb6_row4_col2" class="data row4 col2" >0.831235</td>
#       <td id="T_efcb6_row4_col3" class="data row4 col3" >0.019476</td>
#       <td id="T_efcb6_row4_col4" class="data row4 col4" >0.008710</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Treinamento final e Avaliação

# %%
X_train_transformed = transformers_X['SVM'].fit_transform(df_X_train)
X_test_transformed = transformers_X['SVM'].transform(df_X_test)
y_train = transformer_y.fit_transform(df_y_train)
y_test  = transformer_y.transform(df_y_test)

# %%
models['SVM'] = SVC(C=0.0017158226880264926,
                    gamma=0.00000192914796952792,
                    kernel='rbf',
                    probability=True,
                    random_state=7)
models['SVM'].fit(X=X_train_transformed,
                  y=y_train.reshape(-1))
# Out:
# SVC(C=0.0017158226880264926, gamma=1.92914796952792e-06, probability=True,
#     random_state=7)

# %%
metrics_final_comparison['SVM'] = evaluate(
    model=models['SVM'],
    X_train=X_train_transformed, X_test=X_test_transformed, y_train=y_train, y_test=y_test,
    beta_fscore=2., threshold=1 / (1 + 1), threshold_step=0.001,
    display_metrics_table=True, plot_confusion_matrix=True, plot_roc_prc=True,
    save_metrics_table=True, save_confusion_matrix=True, save_roc_prc=True,
    path_metrics_table='../reports/tables/model-evaluation_SVM.csv',
    path_confusion_matrix='../reports/figures/confusion-matrix_SVM.png',
    path_roc_prc='../reports/figures/roc-pr-curves_SVM.png',
    model_title=' - SVM')['Teste']
# Out:
# <style type="text/css">
# </style>
# <table id="T_c1aac">
#   <caption>Métricas de Avaliação - SVM</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1aac_level0_col0" class="col_heading level0 col0" >Treinamento</th>
#       <th id="T_c1aac_level0_col1" class="col_heading level0 col1" >Teste</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1aac_level0_row0" class="row_heading level0 row0" >Acurácia</th>
#       <td id="T_c1aac_row0_col0" class="data row0 col0" >0.795</td>
#       <td id="T_c1aac_row0_col1" class="data row0 col1" >0.800</td>
#     </tr>
#     <tr>
#       <th id="T_c1aac_level0_row1" class="row_heading level0 row1" >Precisão</th>
#       <td id="T_c1aac_row1_col0" class="data row1 col0" >0.626</td>
#       <td id="T_c1aac_row1_col1" class="data row1 col1" >0.637</td>
#     </tr>
#     <tr>
#       <th id="T_c1aac_level0_row2" class="row_heading level0 row2" >Recall</th>
#       <td id="T_c1aac_row2_col0" class="data row2 col0" >0.561</td>
#       <td id="T_c1aac_row2_col1" class="data row2 col1" >0.567</td>
#     </tr>
#     <tr>
#       <th id="T_c1aac_level0_row3" class="row_heading level0 row3" >F1-Score</th>
#       <td id="T_c1aac_row3_col0" class="data row3 col0" >0.592</td>
#       <td id="T_c1aac_row3_col1" class="data row3 col1" >0.600</td>
#     </tr>
#     <tr>
#       <th id="T_c1aac_level0_row4" class="row_heading level0 row4" >F$_{\beta}$-Score</th>
#       <td id="T_c1aac_row4_col0" class="data row4 col0" >0.573</td>
#       <td id="T_c1aac_row4_col1" class="data row4 col1" >0.580</td>
#     </tr>
#     <tr>
#       <th id="T_c1aac_level0_row5" class="row_heading level0 row5" >AUROC</th>
#       <td id="T_c1aac_row5_col0" class="data row5 col0" >-----</td>
#       <td id="T_c1aac_row5_col1" class="data row5 col1" >0.847</td>
#     </tr>
#     <tr>
#       <th id="T_c1aac_level0_row6" class="row_heading level0 row6" >AUPRC</th>
#       <td id="T_c1aac_row6_col0" class="data row6 col0" >-----</td>
#       <td id="T_c1aac_row6_col1" class="data row6 col1" >0.665</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Salvando e Carregando os Modelos Treinados

# %%
save_models(models, path='../models/', format='.pkl')

# %%
models = load_models(['LR', 'DT', 'KNN', 'RF', 'SVM'], path='../models/', format='.pkl')

# %% [markdown]
# # Comparação Final entre Modelos

# %% [markdown]
# #### **Observações da comparação final:**
# - Qualquer modelo obteve performance consideralmente melhor do que os modelos aleatórios (**RG** e **IRG**);
# - A Regressão Logística (**LR**) e a Árvore de Decisão (**DT**), por mais que não tenham sido campeãs estritas em nenhuma métrica, oferecem valores bem competitivos de precisão (ambas) e *AUC* (**LR**) com relação aos melhores modelos, sem contar o fato de serem os modelos mais interpretáveis e computacionalmente leves;
# - O modelo de Floresta Aleatória (**RF**) foi o **campeão em Precisão e *AUC***. Apesar disso, o seu *Recall* deixa a desejar, e em termos de visão de negócio, essa métrica é mais importante neste projeto;
# - O modelo de Máquinas de Vetores de Suporte (**SVM**) foi o **campeão em *Recall***. Apesar disso, a sua Precisão deixa a desejar, mas como o *Recall* tende a ser a métrica mais importante neste projeto, o seu $\text{F}_{\beta}\text{ -Score}$ com peso $\beta=2$ para o *Recall* também foi o melhor;
# - O modelo de Análise Discriminante *Naive Bayes* (**NB**), apesar de não ter sido campeão estrito, teve métricas quase iguais ao **SVM**, com um *Recall* levemente menor, ao passo que a Precisão foi um pouco maior, $\text{F}_{1}\text{ -Score}$ campeão e $\text{F}_{\beta}\text{ -Score}$ praticamente igual, o que o torna também como uma segunda opção mais leve e com construção probabilística, se considerarmos que o *Recall* tornou o *SVM* o campeão geral;
# - O modelo de K-Vizinhos mais Próximos (**KNN**) não se mostrou com nenhuma vantagem competitiva; também não esteve entre os que mais deixaram a desejar, sendo um intermediário em todas as métricas.
#
# #### **Conclusão:** O modelo **SVM**, ou até mesmo o **NB**, devem ser escolhidos.

# %%
metrics_final_comparison = evaluate_all_models_and_get_final_comparison_dict(models=models,
                                                                             transformers_X=transformers_X, transformer_y=transformer_y,
                                                                             df_X_train=df_X_train, df_X_test=df_X_test,
                                                                             df_y_train=df_y_train, df_y_test=df_y_test,
                                                                             threshold=0.5, beta_fscore=2.)

# %%
display_final_comparison_with_highlight(metrics_final_comparison_dict=metrics_final_comparison,
                                        table_title='Métricas no Conjunto de Testes - Comparação Final - Limiar 0.5',
                                        save_table=True, path_table='../reports/tables/final-comparison_standard-threshold.csv')
# Out:
# <style type="text/css">
# #T_2d4c6_row0_col0, #T_2d4c6_row1_col3, #T_2d4c6_row2_col2, #T_2d4c6_row3_col2, #T_2d4c6_row4_col2, #T_2d4c6_row5_col0, #T_2d4c6_row6_col3 {
#   color: white;
#   font-weight: bold;
#   background-color: darkblue;
# }
# #T_2d4c6_row0_col1, #T_2d4c6_row1_col2, #T_2d4c6_row2_col1, #T_2d4c6_row3_col1, #T_2d4c6_row4_col1, #T_2d4c6_row5_col1, #T_2d4c6_row6_col2 {
#   color: white;
#   font-weight: bold;
#   background-color: tomato;
# }
# #T_2d4c6_row0_col3, #T_2d4c6_row1_col1, #T_2d4c6_row2_col4, #T_2d4c6_row3_col0, #T_2d4c6_row4_col4, #T_2d4c6_row5_col3, #T_2d4c6_row6_col0 {
#   color: white;
#   background-color: steelblue;
# }
# </style>
# <table id="T_2d4c6">
#   <caption>Métricas no Conjunto de Testes - Comparação Final - Limiar 0.5</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d4c6_level0_col0" class="col_heading level0 col0" >LR</th>
#       <th id="T_2d4c6_level0_col1" class="col_heading level0 col1" >DT</th>
#       <th id="T_2d4c6_level0_col2" class="col_heading level0 col2" >KNN</th>
#       <th id="T_2d4c6_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_2d4c6_level0_col4" class="col_heading level0 col4" >SVM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d4c6_level0_row0" class="row_heading level0 row0" >Acurácia</th>
#       <td id="T_2d4c6_row0_col0" class="data row0 col0" >0.810</td>
#       <td id="T_2d4c6_row0_col1" class="data row0 col1" >0.793</td>
#       <td id="T_2d4c6_row0_col2" class="data row0 col2" >0.794</td>
#       <td id="T_2d4c6_row0_col3" class="data row0 col3" >0.809</td>
#       <td id="T_2d4c6_row0_col4" class="data row0 col4" >0.800</td>
#     </tr>
#     <tr>
#       <th id="T_2d4c6_level0_row1" class="row_heading level0 row1" >Precisão</th>
#       <td id="T_2d4c6_row1_col0" class="data row1 col0" >0.672</td>
#       <td id="T_2d4c6_row1_col1" class="data row1 col1" >0.677</td>
#       <td id="T_2d4c6_row1_col2" class="data row1 col2" >0.612</td>
#       <td id="T_2d4c6_row1_col3" class="data row1 col3" >0.686</td>
#       <td id="T_2d4c6_row1_col4" class="data row1 col4" >0.637</td>
#     </tr>
#     <tr>
#       <th id="T_2d4c6_level0_row2" class="row_heading level0 row2" >Recall</th>
#       <td id="T_2d4c6_row2_col0" class="data row2 col0" >0.552</td>
#       <td id="T_2d4c6_row2_col1" class="data row2 col1" >0.418</td>
#       <td id="T_2d4c6_row2_col2" class="data row2 col2" >0.612</td>
#       <td id="T_2d4c6_row2_col3" class="data row2 col3" >0.518</td>
#       <td id="T_2d4c6_row2_col4" class="data row2 col4" >0.567</td>
#     </tr>
#     <tr>
#       <th id="T_2d4c6_level0_row3" class="row_heading level0 row3" >F1-Score</th>
#       <td id="T_2d4c6_row3_col0" class="data row3 col0" >0.606</td>
#       <td id="T_2d4c6_row3_col1" class="data row3 col1" >0.517</td>
#       <td id="T_2d4c6_row3_col2" class="data row3 col2" >0.612</td>
#       <td id="T_2d4c6_row3_col3" class="data row3 col3" >0.590</td>
#       <td id="T_2d4c6_row3_col4" class="data row3 col4" >0.600</td>
#     </tr>
#     <tr>
#       <th id="T_2d4c6_level0_row4" class="row_heading level0 row4" >F$_{\beta}$-Score</th>
#       <td id="T_2d4c6_row4_col0" class="data row4 col0" >0.573</td>
#       <td id="T_2d4c6_row4_col1" class="data row4 col1" >0.452</td>
#       <td id="T_2d4c6_row4_col2" class="data row4 col2" >0.612</td>
#       <td id="T_2d4c6_row4_col3" class="data row4 col3" >0.545</td>
#       <td id="T_2d4c6_row4_col4" class="data row4 col4" >0.580</td>
#     </tr>
#     <tr>
#       <th id="T_2d4c6_level0_row5" class="row_heading level0 row5" >AUROC</th>
#       <td id="T_2d4c6_row5_col0" class="data row5 col0" >0.858</td>
#       <td id="T_2d4c6_row5_col1" class="data row5 col1" >0.837</td>
#       <td id="T_2d4c6_row5_col2" class="data row5 col2" >0.847</td>
#       <td id="T_2d4c6_row5_col3" class="data row5 col3" >0.854</td>
#       <td id="T_2d4c6_row5_col4" class="data row5 col4" >0.847</td>
#     </tr>
#     <tr>
#       <th id="T_2d4c6_level0_row6" class="row_heading level0 row6" >AUPRC</th>
#       <td id="T_2d4c6_row6_col0" class="data row6 col0" >0.679</td>
#       <td id="T_2d4c6_row6_col1" class="data row6 col1" >0.665</td>
#       <td id="T_2d4c6_row6_col2" class="data row6 col2" >0.658</td>
#       <td id="T_2d4c6_row6_col3" class="data row6 col3" >0.683</td>
#       <td id="T_2d4c6_row6_col4" class="data row6 col4" >0.665</td>
#     </tr>
#   </tbody>
# </table>
